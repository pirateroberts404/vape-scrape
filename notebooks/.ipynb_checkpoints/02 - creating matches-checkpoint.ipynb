# %%
import pandas as pd
import numpy as np
import re
import nltk
import json

# %%
tmp1 = pd.read_csv("..//data/weedmaps_joined.csv")

# %% [markdown]
# - is there many licenses that have conflicing
# - create a "licenses_not_joined" file
#  - collect statistics on how many licenses joined correctly with the adult-use / medicinal column.

# %%
pd.crosstab(tmp1["license_type"], tmp1["Adult-Use/Medicinal"])
# Out:
# Adult-Use/Medicinal  Adult-Use  BOTH  Medicinal
# license_type
# hybrid                      27   313          1
# medical                      2    40         26
# recreational                14    37          0

# %%
master_list = pd.read_csv("..//data/searchResults.csv")
left_to_merge = pd.read_csv("..//data/weedmaps_not_joined.csv")

# %% [markdown]
# ## Clean data a bit
# - remove hyphen
# - get zip code from master list
# - get city from Premise Address

# %%
def remove_symbol(row, col, string, string_repl):
    if pd.isnull(row[col]):
        return ""
    
    return re.sub("\(|\)|\s+|\.", "", row[col].replace(string, string_repl)).strip()

# %%
left_to_merge.phone = left_to_merge.apply(lambda row: remove_symbol(row, "phone", "-", ""), axis = 1)

# %%
def break_fields(row, col, string):
    if pd.isnull(row[col]):
        return ""
    
    test = re.search(string, row[col], flags = re.I)
    if test != None:
        return test.group()
    
    return ""

# %%
master_list["zip_code"] = master_list.apply(lambda row: break_fields(row, "Premise Address", "([0-9]{5})|([0-9]{9})"), axis = 1)

# %%
def get_city(row, col):
    street_abbrev = [" w ", " blvd ", " st ", " rd ", " pkwy ", " ave ", 
                     " ctr ", " cir ", " ct ", " dr ", " ln ", " lk ", 
                     " lp ", " pl ", " sq ", " tr ", " e ", " n ", " s ", 
                     " hwy ", " way ", " wy ", ]
    fix = {"[0-9]": "", "\s+": " ", "san fran": "san francisco", "avenue": "", "highway": ""}
    if pd.isnull(row[col]):
        return ""
    
    left_limit = 0
    check_list = []
    for i in street_abbrev:
        street = re.search(i, row[col], flags = re.I)
        if street != None:  
            check_list.append(street.end())
        else:
            check_list.append(0)
    left_limit = max(check_list)
    
    right_limit = re.search(", ", row[col], flags = re.I)
    if right_limit != None:
        right_limit = right_limit.start()
        
    tmp = row[col][left_limit: right_limit].strip()
    
    for i in fix:
        tmp = re.sub(i, fix[i], tmp, flags = re.I)
        
    return tmp.strip()

# %%
master_list["city"] = master_list.apply(lambda row: get_city(row, "Premise Address"), axis = 1).str.lower()

# %%
def get_email(row, col):
    replace = {"email": "", "Email": "", "-": ""}
    if pd.isnull(row[col]):
        return ""
    check = re.search("email-.+?@.+?\s", row[col], flags = re.I)
    
    if check is not None:
        check = check.group()
        for i in replace:
            check = check.replace(i, replace[i])
        return check
    
    return ""

# %%
def get_website(row, col):
    replace = {"website": "", "Website": "", "-": ""}
    if pd.isnull(row[col]):
        return ""
    check = re.search("email-.+?@.+?\s", row[col], flags = re.I)
    
    if check is not None:
        check = check.group()
        for i in replace:
            check = check.replace(i, replace[i])
        return check
    
    return ""

# %%
master_list["email"] = master_list.apply(lambda row: get_email(row, "Business Contact Information"), axis = 1)

# %%
master_list["Business Contact Information"][0]
# Out:
# 'MOVOCAN : Email- medigroupangel@gmail.com : Phone- 7605409358 : Website- www.movocan.com'

# %%
def search_column(row, col, string):
    if pd.isnull(row[col]):
        return False
    elif re.search(string, row[col], flags = re.I) != None:
        return True
    else:
        return False

# %%
def update_matches(test, matches, num):
    
    for match in test.index:
        if match not in matches:
            matches.update({match: num})
        else:
            matches[match] += num
    
    return matches

# %%
def suggest_stores(left_to_merge, master_list):
    
    tmp = 0
    ranked_indexes = {}
    unique_cities = master_list.city.unique()

    for index in left_to_merge.id:
        comparison = left_to_merge[left_to_merge.id == index]
        matches = {}

        # check phone
        #print(ranked_indexes)
        print(comparison.phone.iloc[0])
        print(comparison.zip_code.iloc[0])
        print(comparison.city.iloc[0])
        #print()
        
        test = master_list[master_list.apply(lambda row: search_column(row, "Business Contact Information", comparison.phone.iloc[0]), axis = 1)]    
        matches = update_matches(test, matches, 2)

        # check zip
        test = master_list[master_list.apply(lambda row: search_column(row, "zip_code", comparison.zip_code.iloc[0]), axis = 1)]    
        matches = update_matches(test, matches, 1)

        # check city
        # first find closest city wrt levenschtein distance
        best_city = sorted({x: nltk.edit_distance(comparison.city.iloc[0].lower(), x) for x in unique_cities}.items(), key = lambda x: x[1])[0][0]
        #print(best_city)
        # then find those indices
        test = master_list[master_list.apply(lambda row: search_column(row, "city", best_city), axis = 1)]    
        matches = update_matches(test, matches, 1)

        # sort matches
        ranked_indexes.update({index: sorted(matches.items(), key = lambda x: x[1], reverse = True)})
        
        tmp += 1
        if tmp > 20:
            break

    return ranked_indexes

# %%
all_matches = suggest_stores(left_to_merge, master_list)
# Out:
# 0000000000
# 94044
# Pacifica
# 7072102271
# 94559
# Napa
# 7076525018
# 94590
# Vallejo
# 5107762965
# 94841
# Richmond
# 5109251266
# 94608
# Emeryville
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-fbf829e26225> in <module>
# ----> 1 all_matches = suggest_stores(left_to_merge, master_list)
#
# <ipython-input-21-77c1f18a2c8e> in suggest_stores(left_to_merge, master_list)
#      16         #print()
#      17
# ---> 18         test = master_list[master_list.apply(lambda row: search_column(row, "Business Contact Information", comparison.phone.iloc[0]), axis = 1)]
#      19         matches = update_matches(test, matches, 2)
#      20
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     240                                           axis=self.axis,
#     241                                           dummy=dummy,
# --> 242                                           labels=labels)
#     243                 return self.obj._constructor_sliced(result, index=labels)
#     244             except Exception:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.reduce()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-21-77c1f18a2c8e> in <lambda>(row)
#      16         #print()
#      17
# ---> 18         test = master_list[master_list.apply(lambda row: search_column(row, "Business Contact Information", comparison.phone.iloc[0]), axis = 1)]
#      19         matches = update_matches(test, matches, 2)
#      20
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
# -> 4375                 return self[name]
#    4376             return object.__getattribute__(self, name)
#    4377
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2666
#    2667         # shortcut if we are an actual column
# -> 2668         is_mi_columns = isinstance(self.columns, MultiIndex)
#    2669         try:
#    2670             if key in self.columns and not is_mi_columns:
#
# KeyboardInterrupt:

# %%
with open("..//data//matches.json", "w") as f:
    json.dump(all_matches, f)

# %% [markdown]
# ## match email

# %%
left_to_merge.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     id                            name state  \
# 0          11            11  50268                            Lytt    CA
# 1          14            14  60567  Harvest of Napa (Newly Opened)    CA
# 2          15            15  49957              Mendocino Organics    CA
# 3          16            16  20208    Fly Fast Delivery - Richmond    CA
# 4          22            22  57685           East Bay Therapeutics    CA
#
#          city   latitude   longitude license_type                    address  \
# 0    Pacifica  37.634507 -122.491800      medical  1905 Palmetto Ave. Unit B
# 1        Napa  38.297243 -122.301418      medical         2449 Second Street
# 2     Vallejo  38.109695 -122.253425      medical         539 A Tennessee ST
# 3    Richmond  37.964331 -122.318325      medical                        NaN
# 4  Emeryville  37.838307 -122.290292       hybrid       5745 Peladeau Street
#
#        ...        retailer_services           phone adult_use_cultivation  \
# 0      ...               storefront      0000000000                   NaN
# 1      ...               storefront    707.210.2271                   NaN
# 2      ...               storefront   (707)652-5018                   NaN
# 3      ...                 delivery  (510) 776-2965                   NaN
# 4      ...               storefront  (510) 925-1266                   NaN
#
#   adult_use_nonstorefront adult_use_retail distributor  medical_cultivation  \
# 0                     NaN              NaN         NaN                  NaN
# 1                     NaN              NaN         NaN                  NaN
# 2                     NaN              NaN         NaN                  NaN
# 3                     NaN              NaN         NaN                  NaN
# 4                     NaN       A100000368         NaN                  NaN
#
#   medical_nonstorefront medical_retail  microbusiness
# 0                   NaN            NaN            NaN
# 1                   NaN            NaN            NaN
# 2                   NaN            NaN            NaN
# 3                   NaN            NaN            NaN
# 4                   NaN     M100000420            NaN
#
# [5 rows x 24 columns]

# %%
master_list[master_list.apply(lambda row: search_column(row, "Business Contact Information", "vhhc420@gmail.com"), axis = 1)]
# Out:
#            License Number                              License Type  \
# 1869  C11-18-0000083-TEMP  Cannabis - Distributor Temporary License
#
#        Business Owner                       Business Contact Information  \
# 1869  Greogry Schoepp  VHHC, LLC : Email- vhhc420@gmail.com : Phone- ...
#
#              Business Structure                        Premise Address  \
# 1869  Limited Liability Company  VALLEJO, CA 945904430 County: SOLANO
#
#       Status  Issue Date Expiration Date                 Activities  \
# 1869  Active  06/11/2019      08/15/2018  N/A for this license type
#
#      Adult-Use/Medicinal zip_code
# 1869                BOTH    94590

# %% [markdown]
# ## match phone

# %%
master_list[master_list.apply(lambda row: search_column(row, "Business Contact Information", "7076525018"), axis = 1)]
# Out:
#            License Number                              License Type  \
# 1869  C11-18-0000083-TEMP  Cannabis - Distributor Temporary License
#
#        Business Owner                       Business Contact Information  \
# 1869  Greogry Schoepp  VHHC, LLC : Email- vhhc420@gmail.com : Phone- ...
#
#              Business Structure                        Premise Address  \
# 1869  Limited Liability Company  VALLEJO, CA 945904430 County: SOLANO
#
#       Status  Issue Date Expiration Date                 Activities  \
# 1869  Active  06/11/2019      08/15/2018  N/A for this license type
#
#      Adult-Use/Medicinal zip_code
# 1869                BOTH    94590

# %% [markdown]
# ## match zip

# %%
master_list[master_list.apply(lambda row: search_column(row, "zip_code", "94903"), axis = 1)]
# Out:
