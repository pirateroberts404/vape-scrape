# %%
import pandas as pd
import numpy as np
import os
import glob
import re
import requests
import json

# %% [markdown]
# # scrape from this:
# https://api-g.weedmaps.com/discovery/v1/listings?filter%5Bany_retailer_services%5D%5B%5D=doctor&filter%5Bany_retailer_services%5D%5B%5D=storefront&filter%5Bany_retailer_services%5D%5B%5D=delivery&filter%5Bbounding_box%5D=36.54494944148322,-133.330078125,50.45750402042058,-113.31298828125&page_size=100&size=2000

# %%
tmp = requests.get("https://api-g.weedmaps.com/discovery/v1/listings?filter%5Bany_retailer_services%5D%5B%5D=storefront&filter%5Bany_retailer_services%5D%5B%5D=delivery&filter%5Bbounding_box%5D=34.866778207689634,-120.63949584960938,37.78551286273958,-119.43350219726562&page_size=150&size=10000").json()

# %%
len(np.unique([x["id"] for x in tmp["data"]["listings"]]))
# Out:
# 125

# %%
len(tmp["data"]["listings"])
# Out:
# 125

# %%
def parse_response(response):
    """
    obj: response from Weedmaps API
    """
    
    response = json.loads(response)["data"]["listings"]
    
    if len(response) >= 0:

# %%
import sqlite3

conn = sqlite3.connect("..//data//weedmaps.db")
c = conn.cursor()

c.execute("""
DROP TABLE store;
""")

c.execute("""
DROP TABLE strain;
""")

c.execute("""
CREATE TABLE store (
    id INT UNIQUE, name TEXT, state TEXT, city TEXT, latitude REAL, longitude REAL,
    license_type TEXT, address TEXT, rating REAL, reviews_count INT,
    zip_code TEXT, web_url TEXT, retailer_services TEXT, phone TEXT, 
    adult_use_cultivation TEXT, adult_use_nonstorefront TEXT,
    adult_use_retail TEXT, distributor TEXT, medical_cultivation TEXT,
    medical_nonstorefront TEXT, medical_retail TEXT, microbusiness TEXT
);
""")

c.execute("""
CREATE TABLE strain (
    id INT, name TEXT, strain TEXT, price REAL, 
    amount TEXT, unit TEXT, grams_per_eighth REAL
);
""")

conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-414174099b55> in <module>
#       6 c.execute("""
#       7 DROP TABLE store;
# ----> 8 """)
#       9
#      10 c.execute("""
#
# OperationalError: no such table: store

# %%
conn = sqlite3.connect("..//data//weedmaps.db")
c = conn.cursor()
c.execute("SELECT * FROM store;")
rows = c.fetchall()
c.execute("SELECT * FROM strain;")
row2 = c.fetchall()
conn.commit()
conn.close()

# %%
row2
# Out:
# [(23519, 'Black Water 25.90%', 'Indica', 49.0, '1/8', 'ounce', 3.5),
#  (23519, 'Black Water 25.90%', 'Indica', 95.0, '1/4', 'ounce', 3.5),
#  (23519, 'Black Water 25.90%', 'Indica', 185.0, '1/2', 'ounce', 3.5),
#  (23519, 'Black Water 25.90%', 'Indica', 365.0, '1', 'ounce', 3.5),
#  (23519, 'Blackberry Kush', 'Indica', 29.99, '1/8', 'ounce', 3.5),
#  (23519, 'Blackberry Kush', 'Indica', 55.0, '1/4', 'ounce', 3.5),
#  (23519, 'Blackberry Kush', 'Indica', 105.0, '1/2', 'ounce', 3.5),
#  (23519, 'Blackberry Kush', 'Indica', 200.0, '1', 'ounce', 3.5),
#  (23519, 'Blue Skittlez 25.41%', 'Indica', 16.0, '1', 'gram', 3.5),
#  (23519, 'Blue Skittlez 25.41%', 'Indica', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Blue Skittlez 25.41%', 'Indica', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Blue Skittlez 25.41%', 'Indica', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Blue Skittlez 25.41%', 'Indica', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Cookies - Hi-Octane', 'Indica', 30.0, '1/8', 'ounce', 3.5),
#  (23519, 'Cookies - Hi-Octane', 'Indica', 58.0, '1/4', 'ounce', 3.5),
#  (23519, 'Cookies - Hi-Octane', 'Indica', 116.0, '1/2', 'ounce', 3.5),
#  (23519, 'Cookies - Hi-Octane', 'Indica', 235.0, '1', 'ounce', 3.5),
#  (23519, 'Cookies by Smooth 23.53%', 'Indica', 29.0, '1/8', 'ounce', 3.5),
#  (23519, 'Cookies by Smooth 23.53%', 'Indica', 55.0, '1/4', 'ounce', 3.5),
#  (23519, 'Cookies by Smooth 23.53%', 'Indica', 105.0, '1/2', 'ounce', 3.5),
#  (23519, 'Cookies by Smooth 23.53%', 'Indica', 200.0, '1', 'ounce', 3.5),
#  (23519, "Do-si-Do's 23.67%", 'Indica', 45.0, '1/8', 'ounce', 3.5),
#  (23519, "Do-si-Do's 23.67%", 'Indica', 85.0, '1/4', 'ounce', 3.5),
#  (23519, "Do-si-Do's 23.67%", 'Indica', 165.0, '1/2', 'ounce', 3.5),
#  (23519, "Do-si-Do's 23.67%", 'Indica', 325.0, '1', 'ounce', 3.5),
#  (23519,
#   'Granddaddy Purple 18.20% // BOGO',
#   'Indica',
#   54.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Granddaddy Purple 18.20% // BOGO',
#   'Indica',
#   105.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Granddaddy Purple 18.20% // BOGO',
#   'Indica',
#   200.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519, 'Herijuana 32.19%', 'Indica', 55.0, '1/8', 'ounce', 3.5),
#  (23519, 'Herijuana 32.19%', 'Indica', 105.0, '1/4', 'ounce', 3.5),
#  (23519, 'Herijuana 32.19%', 'Indica', 205.0, '1/2', 'ounce', 3.5),
#  (23519, 'Herijuana 32.19%', 'Indica', 400.0, '1', 'ounce', 3.5),
#  (23519, 'Hi-Octane 20.00% by Cookies', 'Indica', 30.0, '1/8', 'ounce', 3.5),
#  (23519, 'Hi-Octane 20.00% by Cookies', 'Indica', 58.0, '1/4', 'ounce', 3.5),
#  (23519, 'Hi-Octane 20.00% by Cookies', 'Indica', 116.0, '1/2', 'ounce', 3.5),
#  (23519, 'Hi-Octane 20.00% by Cookies', 'Indica', 235.0, '1', 'ounce', 3.5),
#  (23519,
#   'Mendo Breath by Purple Star 21.99%',
#   'Indica',
#   39.99,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Breath by Purple Star 21.99%',
#   'Indica',
#   77.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Breath by Purple Star 21.99%',
#   'Indica',
#   150.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Breath by Purple Star 21.99%',
#   'Indica',
#   295.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Hash Plant 16.94% // BOGO',
#   'Indica',
#   54.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Hash Plant 16.94% // BOGO',
#   'Indica',
#   105.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Hash Plant 16.94% // BOGO',
#   'Indica',
#   200.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Time Lapse 22% // TOP SHELF SPECIAL',
#   'Indica',
#   13.99,
#   '1',
#   'gram',
#   3.5),
#  (23519,
#   'Mendo Time Lapse 22% // TOP SHELF SPECIAL',
#   'Indica',
#   33.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Time Lapse 22% // TOP SHELF SPECIAL',
#   'Indica',
#   66.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Time Lapse 22% // TOP SHELF SPECIAL',
#   'Indica',
#   132.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Mendo Time Lapse 22% // TOP SHELF SPECIAL',
#   'Indica',
#   264.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519,
#   'Pre 98 Bubba 14.38% // Special',
#   'Indica',
#   25.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Pre 98 Bubba 14.38% // Special',
#   'Indica',
#   50.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Pre 98 Bubba 14.38% // Special',
#   'Indica',
#   95.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519, 'Pre 98 Bubba 14.38% // Special', 'Indica', 180.0, '1', 'ounce', 3.5),
#  (23519, 'Presidential Kush 24.24%', 'Indica', 16.0, '1', 'gram', 3.5),
#  (23519, 'Presidential Kush 24.24%', 'Indica', 49.0, '1/8', 'ounce', 3.5),
#  (23519, 'Presidential Kush 24.24%', 'Indica', 95.0, '1/4', 'ounce', 3.5),
#  (23519, 'Presidential Kush 24.24%', 'Indica', 185.0, '1/2', 'ounce', 3.5),
#  (23519, 'Presidential Kush 24.24%', 'Indica', 365.0, '1', 'ounce', 3.5),
#  (23519, 'Purple Kush 23.92%', 'Indica', 15.0, '1', 'gram', 3.5),
#  (23519, 'Purple Kush 23.92%', 'Indica', 43.0, '1/8', 'ounce', 3.5),
#  (23519, 'Purple Kush 23.92%', 'Indica', 82.0, '1/4', 'ounce', 3.5),
#  (23519, 'Purple Kush 23.92%', 'Indica', 160.0, '1/2', 'ounce', 3.5),
#  (23519, 'Purple Kush 23.92%', 'Indica', 315.0, '1', 'ounce', 3.5),
#  (23519, 'Purple Punch 22.2%', 'Indica', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Purple Punch 22.2%', 'Indica', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Purple Punch 22.2%', 'Indica', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Purple Punch 22.2%', 'Indica', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Skittlez 18.06%', 'Indica', 39.99, '1/8', 'ounce', 3.5),
#  (23519, 'Skittlez 18.06%', 'Indica', 77.0, '1/4', 'ounce', 3.5),
#  (23519, 'Skittlez 18.06%', 'Indica', 150.0, '1/2', 'ounce', 3.5),
#  (23519, 'Skittlez 18.06%', 'Indica', 295.0, '1', 'ounce', 3.5),
#  (23519, 'Skywalker OG 22.99%', 'Indica', 29.99, '1/8', 'ounce', 3.5),
#  (23519, 'Skywalker OG 22.99%', 'Indica', 55.0, '1/4', 'ounce', 3.5),
#  (23519, 'Skywalker OG 22.99%', 'Indica', 105.0, '1/2', 'ounce', 3.5),
#  (23519, 'Skywalker OG 22.99%', 'Indica', 200.0, '1', 'ounce', 3.5),
#  (23519, 'White Tahoe Cookies 23.24%', 'Indica', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'White Tahoe Cookies 23.24%', 'Indica', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'White Tahoe Cookies 23.24%', 'Indica', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'White Tahoe Cookies 23.24%', 'Indica', 325.0, '1', 'ounce', 3.5),
#  (23519, 'White Walker 25.5%', 'Indica', 49.0, '1/8', 'ounce', 3.5),
#  (23519, 'White Walker 25.5%', 'Indica', 95.0, '1/4', 'ounce', 3.5),
#  (23519, 'White Walker 25.5%', 'Indica', 185.0, '1/2', 'ounce', 3.5),
#  (23519, 'White Walker 25.5%', 'Indica', 365.0, '1', 'ounce', 3.5),
#  (23519,
#   'Zombie Hash Plant 21.09% // TOP SHELF SPECIAL',
#   'Indica',
#   35.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Zombie Hash Plant 21.09% // TOP SHELF SPECIAL',
#   'Indica',
#   68.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Zombie Hash Plant 21.09% // TOP SHELF SPECIAL',
#   'Indica',
#   130.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Zombie Hash Plant 21.09% // TOP SHELF SPECIAL',
#   'Indica',
#   255.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519,
#   'Marley Natural™ Red - Trident (CBD-rich)',
#   'Sativa',
#   36.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Marley Natural™ Red - Trident (CBD-rich)',
#   'Sativa',
#   69.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Marley Natural™ Red - Trident (CBD-rich)',
#   'Sativa',
#   133.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Marley Natural™ Red - Trident (CBD-rich)',
#   'Sativa',
#   260.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519,
#   'Cherry Vortex 16.24% // 7 GRAM SPECIAL',
#   'Sativa',
#   39.99,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519, 'Dream Poison 18.08% // BOGO', 'Sativa', 54.0, '1/8', 'ounce', 3.5),
#  (23519, 'Dream Poison 18.08% // BOGO', 'Sativa', 105.0, '1/4', 'ounce', 3.5),
#  (23519, 'Dream Poison 18.08% // BOGO', 'Sativa', 200.0, '1/2', 'ounce', 3.5),
#  (23519, 'Durban Poison 21.71%', 'Sativa', 15.0, '1', 'gram', 3.5),
#  (23519, 'Durban Poison 21.71%', 'Sativa', 43.0, '1/8', 'ounce', 3.5),
#  (23519, 'Durban Poison 21.71%', 'Sativa', 82.0, '1/4', 'ounce', 3.5),
#  (23519, 'Durban Poison 21.71%', 'Sativa', 160.0, '1/2', 'ounce', 3.5),
#  (23519, 'Durban Poison 21.71%', 'Sativa', 315.0, '1', 'ounce', 3.5),
#  (23519, 'Green Crack 15.47% // BOGO', 'Sativa', 54.0, '1', 'unit', 3.5),
#  (23519, 'Green Crack 17.99% // SPECIAL', 'Sativa', 30.0, '1/8', 'ounce', 3.5),
#  (23519, 'Green Crack 17.99% // SPECIAL', 'Sativa', 55.0, '1/4', 'ounce', 3.5),
#  (23519,
#   'Green Crack 17.99% // SPECIAL',
#   'Sativa',
#   100.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519, 'Green Crack 17.99% // SPECIAL', 'Sativa', 190.0, '1', 'ounce', 3.5),
#  (23519,
#   'Hopland Blue Dream 16.24% // BOGO',
#   'Sativa',
#   54.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Hopland Blue Dream 16.24% // BOGO',
#   'Sativa',
#   105.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Hopland Blue Dream 16.24% // BOGO',
#   'Sativa',
#   200.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519, 'Jack Herer 18.84%', 'Sativa', 15.0, '1', 'gram', 3.5),
#  (23519, 'Jack Herer 18.84%', 'Sativa', 43.0, '1/8', 'ounce', 3.5),
#  (23519, 'Jack Herer 18.84%', 'Sativa', 82.0, '1/4', 'ounce', 3.5),
#  (23519, 'Jack Herer 18.84%', 'Sativa', 160.0, '1/2', 'ounce', 3.5),
#  (23519, 'Jack Herer 18.84%', 'Sativa', 315.0, '1', 'ounce', 3.5),
#  (23519, 'Lemon Cake 23.6%', 'Sativa', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Lemon Cake 23.6%', 'Sativa', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Lemon Cake 23.6%', 'Sativa', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Lemon Cake 23.6%', 'Sativa', 325.0, '1', 'ounce', 3.5),
#  (23519,
#   'Pina Rita 14.51% // OUNCE SPECIAL 50% OFF',
#   'Sativa',
#   176.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519, 'Pina Rita 14.54% // SPECIAL', 'Sativa', 10.0, '1', 'gram', 3.5),
#  (23519, 'Pina Rita 14.54% // SPECIAL', 'Sativa', 25.0, '1/8', 'ounce', 3.5),
#  (23519, 'Pina Rita 14.54% // SPECIAL', 'Sativa', 45.0, '1/4', 'ounce', 3.5),
#  (23519, 'Pina Rita 14.54% // SPECIAL', 'Sativa', 85.0, '1/2', 'ounce', 3.5),
#  (23519, 'Pina Rita 14.54% // SPECIAL', 'Sativa', 170.0, '1', 'ounce', 3.5),
#  (23519,
#   'Platinum Super Silver Haze 23.39% // 35% OFF',
#   'Sativa',
#   50.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Platinum Super Silver Haze 23.39% // 35% OFF',
#   'Sativa',
#   95.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Platinum Super Silver Haze 23.39% // 35% OFF',
#   'Sativa',
#   185.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Platinum Super Silver Haze 23.39% // 35% OFF',
#   'Sativa',
#   365.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519, 'Rocket Fuel 19% // BOGO', 'Sativa', 54.0, '1/8', 'ounce', 3.5),
#  (23519, 'Rocket Fuel 19% // BOGO', 'Sativa', 105.0, '1/4', 'ounce', 3.5),
#  (23519, 'Rocket Fuel 19% // BOGO', 'Sativa', 200.0, '1/2', 'ounce', 3.5),
#  (23519, 'SFV Lambo 25.90%', 'Sativa', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'SFV Lambo 25.90%', 'Sativa', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'SFV Lambo 25.90%', 'Sativa', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'SFV Lambo 25.90%', 'Sativa', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Strawberry Dream 19.46%', 'Sativa', 15.0, '1', 'gram', 3.5),
#  (23519, 'Strawberry Dream 19.46%', 'Sativa', 37.0, '1/8', 'ounce', 3.5),
#  (23519, 'Strawberry Dream 19.46%', 'Sativa', 70.0, '1/4', 'ounce', 3.5),
#  (23519, 'Strawberry Dream 19.46%', 'Sativa', 135.0, '1/2', 'ounce', 3.5),
#  (23519, 'Strawberry Dream 19.46%', 'Sativa', 265.0, '1', 'ounce', 3.5),
#  (23519, 'Korova - Siberian Tiger 3.5g', 'Hybrid', 55.0, '1', 'gram', 3.5),
#  (23519, 'Acai Gelato 19.10% // SPECIAL', 'Hybrid', 35.0, '1/8', 'ounce', 3.5),
#  (23519, 'Acai Gelato 19.10% // SPECIAL', 'Hybrid', 68.0, '1/4', 'ounce', 3.5),
#  (23519,
#   'Acai Gelato 19.10% // SPECIAL',
#   'Hybrid',
#   130.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519, 'Acai Gelato 19.10% // SPECIAL', 'Hybrid', 255.0, '1', 'ounce', 3.5),
#  (23519,
#   'Birthday Cake by Smooth 19.34%',
#   'Hybrid',
#   29.99,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Birthday Cake by Smooth 19.34%',
#   'Hybrid',
#   55.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Birthday Cake by Smooth 19.34%',
#   'Hybrid',
#   105.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519, 'Birthday Cake by Smooth 19.34%', 'Hybrid', 200.0, '1', 'ounce', 3.5),
#  (23519, 'Blueberry Trainwreck 23.54%', 'Hybrid', 16.0, '1', 'gram', 3.5),
#  (23519, 'Blueberry Trainwreck 23.54%', 'Hybrid', 49.0, '1/8', 'ounce', 3.5),
#  (23519, 'Blueberry Trainwreck 23.54%', 'Hybrid', 95.0, '1/4', 'ounce', 3.5),
#  (23519, 'Blueberry Trainwreck 23.54%', 'Hybrid', 185.0, '1/2', 'ounce', 3.5),
#  (23519, 'Blueberry Trainwreck 23.54%', 'Hybrid', 365.0, '1', 'ounce', 3.5),
#  (23519, 'Cookies - Wedding Cake', 'Hybrid', 30.0, '1/8', 'ounce', 3.5),
#  (23519, 'Cookies - Wedding Cake', 'Hybrid', 58.0, '1/4', 'ounce', 3.5),
#  (23519, 'Cookies - Wedding Cake', 'Hybrid', 116.0, '1/2', 'ounce', 3.5),
#  (23519, 'Cookies - Wedding Cake', 'Hybrid', 235.0, '1', 'ounce', 3.5),
#  (23519, 'Dozzi Zo 22%', 'Hybrid', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Dozzi Zo 22%', 'Hybrid', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Dozzi Zo 22%', 'Hybrid', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Dozzi Zo 22%', 'Hybrid', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Flo-y', 'Hybrid', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Flo-y', 'Hybrid', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Flo-y', 'Hybrid', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Flo-y', 'Hybrid', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Gelato by Rainmaker 17.63%', 'Hybrid', 66.0, '1/4', 'ounce', 3.5),
#  (23519, 'Gelato by Rainmaker 17.63%', 'Hybrid', 132.0, '1/2', 'ounce', 3.5),
#  (23519, 'Gelato by Rainmaker 17.63%', 'Hybrid', 264.0, '1', 'ounce', 3.5),
#  (23519, 'Gelato by Smooth 19.53%', 'Hybrid', 29.99, '1/8', 'ounce', 3.5),
#  (23519, 'Gelato by Smooth 19.53%', 'Hybrid', 55.0, '1/4', 'ounce', 3.5),
#  (23519, 'Gelato by Smooth 19.53%', 'Hybrid', 105.0, '1/2', 'ounce', 3.5),
#  (23519, 'Gelato by Smooth 19.53%', 'Hybrid', 200.0, '1', 'ounce', 3.5),
#  (23519, 'Ghost OG 23.33%', 'Hybrid', 45.0, '1/4', 'ounce', 3.5),
#  (23519, 'Ghost OG 23.33%', 'Hybrid', 75.0, '1/2', 'ounce', 3.5),
#  (23519, 'Girl Scout Cookies 19.33%', 'Hybrid', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Girl Scout Cookies 19.33%', 'Hybrid', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Girl Scout Cookies 19.33%', 'Hybrid', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Girl Scout Cookies 19.33%', 'Hybrid', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Gorilla Goo 14.82% // BOGO', 'Hybrid', 54.0, '1/8', 'ounce', 3.5),
#  (23519, 'Gorilla Goo 14.82% // BOGO', 'Hybrid', 105.0, '1/4', 'ounce', 3.5),
#  (23519, 'Gorilla Goo 14.82% // BOGO', 'Hybrid', 200.0, '1/2', 'ounce', 3.5),
#  (23519, 'Jellyfish 11% CBD', 'Hybrid', 36.0, '1/8', 'ounce', 3.5),
#  (23519, 'Jellyfish 11% CBD', 'Hybrid', 69.0, '1/4', 'ounce', 3.5),
#  (23519, 'Jellyfish 11% CBD', 'Hybrid', 133.0, '1/2', 'ounce', 3.5),
#  (23519, 'Jellyfish 11% CBD', 'Hybrid', 260.0, '1', 'ounce', 3.5),
#  (23519,
#   'Key Lime 20.40% // TOP SHELF SPECIAL',
#   'Hybrid',
#   33.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Key Lime 20.40% // TOP SHELF SPECIAL',
#   'Hybrid',
#   66.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Key Lime 20.40% // TOP SHELF SPECIAL',
#   'Hybrid',
#   132.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Key Lime 20.40% // TOP SHELF SPECIAL',
#   'Hybrid',
#   264.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519,
#   'Larry OG 21.18% // TOP SHELF SPECIAL',
#   'Hybrid',
#   15.0,
#   '1',
#   'gram',
#   3.5),
#  (23519,
#   'Larry OG 21.18% // TOP SHELF SPECIAL',
#   'Hybrid',
#   35.0,
#   '1/8',
#   'ounce',
#   3.5),
#  (23519,
#   'Larry OG 21.18% // TOP SHELF SPECIAL',
#   'Hybrid',
#   68.0,
#   '1/4',
#   'ounce',
#   3.5),
#  (23519,
#   'Larry OG 21.18% // TOP SHELF SPECIAL',
#   'Hybrid',
#   130.0,
#   '1/2',
#   'ounce',
#   3.5),
#  (23519,
#   'Larry OG 21.18% // TOP SHELF SPECIAL',
#   'Hybrid',
#   255.0,
#   '1',
#   'ounce',
#   3.5),
#  (23519, 'Lemon OG (High CBD)', 'Hybrid', 39.99, '1/8', 'ounce', 3.5),
#  (23519, 'Mt. Goo 18.35% // BOGO', 'Hybrid', 54.0, '1/8', 'ounce', 3.5),
#  (23519, 'Mt. Goo 18.35% // BOGO', 'Hybrid', 105.0, '1/4', 'ounce', 3.5),
#  (23519, 'Mt. Goo 18.35% // BOGO', 'Hybrid', 200.0, '1/2', 'ounce', 3.5),
#  (23519, 'Orange Fuel 26.30%', 'Hybrid', 49.0, '1/8', 'ounce', 3.5),
#  (23519, 'Orange Fuel 26.30%', 'Hybrid', 95.0, '1/4', 'ounce', 3.5),
#  (23519, 'Orange Fuel 26.30%', 'Hybrid', 185.0, '1/2', 'ounce', 3.5),
#  (23519, 'Orange Fuel 26.30%', 'Hybrid', 365.0, '1', 'ounce', 3.5),
#  (23519, 'Pacific Frost 17.51%', 'Hybrid', 13.99, '1', 'gram', 3.5),
#  (23519, 'Pacific Frost 17.51%', 'Hybrid', 33.0, '1/8', 'ounce', 3.5),
#  (23519, 'Pacific Frost 17.51%', 'Hybrid', 66.0, '1/4', 'ounce', 3.5),
#  (23519, 'Pacific Frost 17.51%', 'Hybrid', 132.0, '1/2', 'ounce', 3.5),
#  (23519, 'Pacific Frost 17.51%', 'Hybrid', 264.0, '1', 'ounce', 3.5),
#  (23519, 'Pre-roll with Shatter', 'Hybrid', 10.0, '1', 'unit', 3.5),
#  (23519, 'Sherbet 21.63%', 'Hybrid', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Sherbet 21.63%', 'Hybrid', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Sherbet 21.63%', 'Hybrid', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Sherbet 21.63%', 'Hybrid', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Skunk Berry 16.31%', 'Hybrid', 45.0, '1/8', 'ounce', 3.5),
#  (23519, 'Skunk Berry 16.31%', 'Hybrid', 85.0, '1/4', 'ounce', 3.5),
#  (23519, 'Skunk Berry 16.31%', 'Hybrid', 165.0, '1/2', 'ounce', 3.5),
#  (23519, 'Skunk Berry 16.31%', 'Hybrid', 325.0, '1', 'ounce', 3.5),
#  (23519, 'Snowman', 'Hybrid', 30.0, '1/8', 'ounce', 3.5),
#  (23519, 'Snowman', 'Hybrid', 58.0, '1/4', 'ounce', 3.5),
#  (23519, 'Snowman', 'Hybrid', 110.0, '1/2', 'ounce', 3.5),
#  (23519, 'Snowman', 'Hybrid', 215.0, '1', 'ounce', 3.5)]

# %%
rows
# Out:
# [(23519,
#   'Purple Star MD',
#   'CA',
#   'San Francisco',
#   37.756634,
#   -122.419033,
#   'recreational',
#   '2520 Mission Street',
#   4.0,
#   378,
#   '94110',
#   'https://weedmaps.com/dispensaries/purple-star-md',
#   'storefront',
#   '(415) 550-1515',
#   '',
#   '',
#   'A10-18-0000139-TEMP',
#   '',
#   '',
#   '',
#   'A10-18-0000139-TEMP',
#   '')]

# %%
row2
# Out:
# [(23519, 'Black Water 25.90%', 'Indica', 49.0, '1/8', 'ounce', 3.5)]

# %%
tmp["data"]["listings"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8c0768daab93> in <module>
# ----> 1 tmp["data"]["listings"]
#
# NameError: name 'tmp' is not defined

# %%
[x["retailer_services"] for x in tmp["data"]["listings"]]
# Out:
# [['storefront'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['storefront'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery']]
