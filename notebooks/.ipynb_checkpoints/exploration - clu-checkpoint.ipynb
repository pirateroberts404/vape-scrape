# %%
import pandas as pd
import numpy as np
import os
import glob
import re
import requests
import json

# %% [markdown]
# # scrape from this:
# https://api-g.weedmaps.com/discovery/v1/listings?filter%5Bany_retailer_services%5D%5B%5D=doctor&filter%5Bany_retailer_services%5D%5B%5D=storefront&filter%5Bany_retailer_services%5D%5B%5D=delivery&filter%5Bbounding_box%5D=36.54494944148322,-133.330078125,50.45750402042058,-113.31298828125&page_size=100&size=2000

# %%
glob.glob("..//data//*")
# Out:
# ['..//data\\ReocrdList20190116.csv', '..//data\\searchResults.csv']

# %%
bcc = pd.read_csv("..//data//searchResults.csv", encoding = "utf-8")

# %%
bcc
# Out:
#              License Number  \
# 0       C11-18-0000939-TEMP
# 1       C10-18-0000287-TEMP
# 2        C9-18-0000229-TEMP
# 3       C12-18-0000217-TEMP
# 4        C9-18-0000230-TEMP
# 5       C11-18-0000940-TEMP
# 6       C11-18-0000941-TEMP
# 7       C10-18-0000288-TEMP
# 8       C11-18-0000942-TEMP
# 9       C13-18-0000159-TEMP
# 10      C11-18-0000943-TEMP
# 11       C9-18-0000231-TEMP
# 12       C9-18-0000232-TEMP
# 13       C9-18-0000233-TEMP
# 14      C12-18-0000218-TEMP
# 15      C11-18-0000944-TEMP
# 16      C11-18-0000945-TEMP
# 17      C11-18-0000946-TEMP
# 18       C9-18-0000234-TEMP
# 19      C12-18-0000219-TEMP
# 20      C11-18-0000947-TEMP
# 21       C9-18-0000235-TEMP
# 22      C12-18-0000220-TEMP
# 23      C10-18-0000289-TEMP
# 24      C11-18-0000948-TEMP
# 25      C13-18-0000160-TEMP
# 26      C12-18-0000221-TEMP
# 27      C13-18-0000161-TEMP
# 28       C9-18-0000236-TEMP
# 29      C11-18-0000949-TEMP
# ...                     ...
# 3422    A12-18-0000021-TEMP
# 3423    A10-18-0000098-TEMP
# 3424    M11-18-0000050-TEMP
# 3425     A9-18-0000012-TEMP
# 3426     A9-18-0000013-TEMP
# 3427    A10-18-0000099-TEMP
# 3428     A9-18-0000014-TEMP
# 3429    A12-18-0000023-TEMP
# 3430    A10-18-0000101-TEMP
# 3431    A11-18-0000043-TEMP
# 3432    A11-18-0000044-TEMP
# 3433    A10-18-0000102-TEMP
# 3434    M11-18-0000052-TEMP
# 3435    A11-18-0000045-TEMP
# 3436     A9-18-0000015-TEMP
# 3437    M11-18-0000055-TEMP
# 3438    M11-18-0000056-TEMP
# 3439    M11-18-0000057-TEMP
# 3440    M10-18-0000150-TEMP
# 3441     A9-18-0000016-TEMP
# 3442     A9-18-0000017-TEMP
# 3443  CEO14-18-0000001-TEMP
# 3444  CEO14-18-0000002-TEMP
# 3445  CEO14-18-0000003-TEMP
# 3446  CEO14-18-0000004-TEMP
# 3447  CEO14-18-0000005-TEMP
# 3448  CEO14-18-0000006-TEMP
# 3449  CEO14-18-0000007-TEMP
# 3450  CEO14-18-0000008-TEMP
# 3451  CEO14-18-0000009-TEMP
#
#                                            License Type  \
# 0              Cannabis - Distributor Temporary License
# 1                 Cannabis - Retailer Temporary License
# 2     Cannabis - Retailer Nonstorefront Temporary Li...
# 22        12/31/2018  Cultivator (less than 10K sq ft), Level 1 Manu...
# 23        12/31/2018                          N/A for this license type
# 24        12/31/2018                          N/A for this license type
# 25        12/31/2018                          N/A for this license type
# 26        12/31/2018  Level 1 Manufacturer, Retailer Non-Storefront,...
# 27        12/31/2018                          N/A for this license type
# 28        12/31/2018                          N/A for this license type
# 29        12/31/2018                          N/A for this license type
# ...              ...                                                ...
# 3422      01/01/2018  Level 1 Manufacturer, Retailer Non-Storefront,...
# 3423      01/01/2018                          N/A for this license type
# 3424      01/01/2018                          N/A for this license type
# 3425      01/01/2018                          N/A for this license type
# 3426      01/01/2018                          N/A for this license type
# 3427      01/01/2018                          N/A for this license type
# 3428      01/01/2018                          N/A for this license type
# 3429      01/01/2018        Level 1 Manufacturer, Distributor, Retailer
# 3430      01/01/2018                          N/A for this license type
# 3431      01/01/2018                          N/A for this license type
# 3432      01/01/2018                          N/A for this license type
# 3433      01/01/2018                          N/A for this license type
# 3434      01/01/2018                          N/A for this license type
# 3435      01/01/2018                          N/A for this license type
# 3436      01/01/2018                          N/A for this license type
# 3437      01/01/2018                          N/A for this license type
# 3438      01/01/2018                          N/A for this license type
# 3439      01/01/2018                          N/A for this license type
# 3440      01/01/2018                          N/A for this license type
# 3441      01/01/2018                          N/A for this license type
# 3442      01/01/2018                          N/A for this license type
# 3443      01/01/2018                          N/A for this license type
# 3444      01/01/2018                          N/A for this license type
# 3445      01/01/2018                          N/A for this license type
# 3446      01/01/2018                          N/A for this license type
# 3447      01/01/2018                          N/A for this license type
# 3448      01/01/2018                          N/A for this license type
# 3449      01/01/2018                          N/A for this license type
# 3450      01/01/2018                          N/A for this license type
# 3451      01/01/2018                          N/A for this license type
#
#      Adult-Use/Medicinal
# 0                   BOTH
# 1              Medicinal
# 2                   BOTH
# 3                   BOTH
# 4                   BOTH
# 5                   BOTH
# 6              Medicinal
# 7                   BOTH
# 8                   BOTH
# 9                   BOTH
# 10             Medicinal
# 11                  BOTH
# 12                  BOTH
# 13                  BOTH
# 14                  BOTH
# 15             Medicinal
# 16                  BOTH
# 17                  BOTH
# 18                  BOTH
# 19                  BOTH
# 20             Adult-Use
# 21                  BOTH
# 22                  BOTH
# 23                  BOTH
# 24                  BOTH
# 25                  BOTH
# 26             Adult-Use
# 27             Medicinal
# 28                  BOTH
# 29                  BOTH
# ...                  ...
# 3422                 NaN
# 3423                BOTH
# 3424                 NaN
# 3425                 NaN
# 3426           Adult-Use
# 3427                BOTH
# 3428           Adult-Use
# 3429                BOTH
# 3430                BOTH
# 3431                 NaN
# 3432           Adult-Use
# 3433                BOTH
# 3434                 NaN
# 3435                BOTH
# 3436                 NaN
# 3437                BOTH
# 3438           Medicinal
# 3439           Medicinal
# 3440           Medicinal
# 3441                BOTH
# 3442                 NaN
# 3443                 NaN
# 3444                 NaN
# 3445                 NaN
# 3446                 NaN
# 3447                 NaN
# 3448                 NaN
# 3449                 NaN
# 3450                 NaN
# 3451                 NaN
#
# [3452 rows x 11 columns]

# %%
tmp = requests.get("https://api-g.weedmaps.com/discovery/v1/listings?filter%5Bany_retailer_services%5D%5B%5D=storefront&filter%5Bany_retailer_services%5D%5B%5D=delivery&filter%5Bbounding_box%5D=34.866778207689634,-120.63949584960938,37.78551286273958,-119.43350219726562&page_size=150&size=10000").json()

# %%
len(np.unique([x["id"] for x in tmp["data"]["listings"]]))
# Out:
# 125

# %%
len(tmp["data"]["listings"])
# Out:
# 125

# %%
def parse_response(response):
    """
    obj: response from Weedmaps API
    """
    
    response = json.loads(response)["data"]["listings"]
    
    if len(response) >= 0:

# %%
import sqlite3

conn = sqlite3.connect("..//data//weedmaps.db")
c = conn.cursor()

c.execute("""
CREATE TABLE store (
    id INT UNIQUE, name TEXT, state TEXT, city TEXT, latitude REAL, longitude REAL,
    license_type TEXT, address TEXT, rating REAL, reviews_count INT,
    zip_code TEXT, web_url TEXT, retailer_services TEXT
);
""")


c.execute("""
CREATE TABLE strain (
    id INT UNIQUE, name TEXT, strain TEXT, phone TEXT,
    recreational INT, medical INT, price REAL
);
""")

conn.commit()
conn.close()

# %%
conn = sqlite3.connect("..//data//weedmaps.db")
c = conn.cursor()
c.execute("SELECT * FROM dispensaries;")
rows = c.fetchall()
conn.commit()
conn.close()

# %%
len(rows)
# Out:
# 0

# %%
x[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2f755f117ac9> in <module>
# ----> 1 x[0]
#
# NameError: name 'x' is not defined

# %%
len(np.unique([x[0] for x in rows]))
# Out:
# 1579

# %%
tmp["data"]["listings"]
# Out:
# [{'id': 46782,
#   'name': 'Heaven - Fresno, Clovis',
#   'slug': 'heaven',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'dispensary',
#   'wmid': 577726659,
#   'latitude': 36.824972,
#   'longitude': -119.790711,
#   'web_url': 'https://weedmaps.com/dispensaries/heaven',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 4.496256876493868,
#   'rating': 4.54869281045752,
#   'reviews_count': 1224,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/dispensaries/000/046/782/avatar/square_fill/1510582922-1503638266-w.jpg',
#    'original_url': 'https://images.weedmaps.com/dispensaries/000/046/782/avatar/original/1510582922-1503638266-w.jpg'},
#   'license_type': 'medical',
#   'address': 'By Appointment Only, Call To Verify',
#   'distance': None,
#   'zip_code': '93710',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>** Follow us on Snap Chat under HeavenFresno ** We love our members in the Central Valley. Thanks for making us so welcome!! FREE edible & pre-roll with every order, as supplies allow. The storefront is open limited hours, and by Appointment Only Minimum storefront donation: 100$ We also offer 24/7 delivery service: Minimum delivery order: 50$ donation Call/text to verify. Prop 215 patients only. We are accepting new vendors, please email for quickest reply.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.824972/-119.790711/402/147/map.png',
#   'open_now': True,
#   'closes_in': 1295,
#   'todays_hours_str': ' 4:20am -  4:19am',
#   'min_age': 18,
#   'menu_items_count': 259,
#   'verified_menu_items_count': 90,
#   'endorsement_badge_count': 83,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['storefront']},
#  {'id': 51712,
#   'name': 'Natural Healing Center - NHC',
#   'slug': 'natural-healing-center',
#   'state': 'CA',
#   'city': 'Grover Beach',
#   'type': 'dispensary',
#   'wmid': 115620192,
#   'latitude': 35.111033,
#   'longitude': -120.61995,
#   'web_url': 'https://weedmaps.com/dispensaries/natural-healing-center',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 3.998438035701838,
#   'rating': 4.292,
#   'reviews_count': 100,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/dispensaries/000/051/712/avatar/square_fill/1529970944-1529002661-image_missing_copy.jpg',
#    'original_url': 'https://images.weedmaps.com/dispensaries/000/051/712/avatar/original/1529970944-1529002661-image_missing_copy.jpg'},
#   'license_type': 'hybrid',
#   'address': '998 Huston Street',
#   'distance': None,
#   'zip_code': '93433',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Welcome to Natural Healing Center (NHC).\xa0 We strive to promote the best in quality, cleanliness, and superior purchase experience.\xa0 Visit us today.</p> <p><strong>Licensed for Adult Use 21+ and Medical 18+</strong></p> <p><strong>Quick Promos:</strong></p> <p>10% Discount For All First Time Customers\xa0(15% off Seniors -First Time Only)</p> <p>10% Discount For Veterns and Senior Members (15% off First Time Only)</p> <p>Happy Hour : 3:20-4:20 - 10% Discount\xa0</p> <p>Loyalty Program for Returning Members: Purchase 2 eighths receive 5% off</p> <p>Purchase 4 eighths (1/2 oz.) receive 10% off</p> <p>Purchase 8 eighths (1oz) receive 15% off - Mix and Match allowed!!</p> <p>Referral 10% discount given to the existing member who referred someone as well as the new patient (Both must make a purchase).</p> <p>*Discounts can not be combined<br>*Prices are subject to change without notice</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/35.111033/-120.61995/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 9:00am -  7:00pm',
#   'min_age': 18,
#   'menu_items_count': 773,
#   'verified_menu_items_count': 16,
#   'endorsement_badge_count': 7,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['storefront']},
#  {'id': 16544,
#   'name': 'The Gas Station - Fresno',
#   'slug': 'the-gas-station-fresno',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 827899746,
#   'latitude': 36.837185,
#   'longitude': -119.790344,
#   'web_url': 'https://weedmaps.com/deliveries/the-gas-station-fresno',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 4.849005064711688,
#   'rating': 4.95873015873016,
#   'reviews_count': 168,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/016/544/avatar/square_fill/1510581234-unnamed.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/016/544/avatar/original/1510581234-unnamed.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93711',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>559-981-0696</p> <p>Free gift with every order</p> <p>Instagram @GasStationFresno</p> <p>Welcome to The Gas Station - Fresno Our mission is to provide the highest quality medicine at the most competitive prices. We provide high quality indoor grown flowers, concentrates and edibles to eligible patients in the Fresno and Clovis area. The Gas Station - Fresno is in compliance with: CALIFORNIA HEALTH AND SAFETY CODE SECTION 11362.5(B)(1)(A) & 11362.7(H), PROPOSITION 215 & SENATE BILL 420.</p> <p>Minimum order: $50</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.837185/-119.790344/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 9:00am -  9:00pm',
#   'min_age': 21,
#   'menu_items_count': 93,
#   'verified_menu_items_count': 19,
#   'endorsement_badge_count': 11,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 766,
#   'name': 'CoExist RX',
#   'slug': 'coexist-rx-san-luis-obispo',
#   'state': 'CA',
#   'city': 'Santa Maria',
#   'type': 'delivery',
#   'wmid': 937898943,
#   'latitude': 34.923656,
#   'longitude': -120.417711,
#   'web_url': 'https://weedmaps.com/deliveries/coexist-rx-san-luis-obispo',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 4.758679976740238,
#   'rating': 4.87213114754098,
#   'reviews_count': 183,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000
LIKE ANY IN THE AREA.</strong></p> <p>What do we mean by that?</p> <p><br>Our customer service, professionalism, and products at the absolute best value for the quality. We offer <strong>in-home consultations</strong> for locals that live in the area and would like to see our products first-hand, or have questions about our products, cannabis, or other products in general. If we do not have an answer for you, we will do our absolute best to find it for you. We aim to keep our delivery times at 30 minutes or less. In order to do this, we employ multiple drivers for a given area to keep our wait times down. We are the longest tenured, fastest growing, delivery service in the area. We deliver from San Luis Opisbo, Shell Beach to Santa Maria, Santa Maria to Lompoc, Lompoc to Solvang and everywhere in between.</p> <p>We also offer\xa0<strong>DISCREET\xa0</strong>brown-bag delivery services to the place of your choosing. We aim to make getting your medicine, the easiest, safest, most discreet, and professional way possible. With updated ETA\'s along route (per request), and clear communication when explaination is needed. We 100% guarantee your satisfaction and will always go out of our way to make sure each product is up to expectations.</p> <p>\xa0</p> <p>VOTED THE #1 DELIVERY DISPENSARY IN SANTA BARBARA COUNTY FOR CONSECUTIVE YEARS! WE ARE LOCALLY OWNED AND OPERATED, AND TRY TO KEEP AS MANY PRODUCTS LOCAL AS POSSIBLE!! Our product, reputation and reviews all speak volumes to the amount of time and care we put in to ensure and maintain a high quality delivery service. We serve many patients in the Santa Maria and Lompoc area with a multitude of products that are serviceable and adaptable to accommodate all budgets. Give us a call and see why we are rated the #1 delivery service in the Central Coast area!!</p> <p><em>Well, what are you wating for?</em></p> <p>\xa0</p> <p>Follow us on Instagram at  ...
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/34.923656/-120.417711/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  8:00pm',
#   'min_age': 18,
#   'menu_items_count': 114,
#   'verified_menu_items_count': 18,
#   'endorsement_badge_count': 5,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 14318,
#   'name': 'Empire powered by Safe Access',
#   'slug': 'safe-access-2-6',
#   'state': 'CA',
#   'city': 'Merced',
#   'type': 'delivery',
#   'wmid': 801230961,
#   'latitude': 37.305433,
#   'longitude': -120.474492,
#   'web_url': 'https://weedmaps.com/deliveries/safe-access-2-6',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 4.729483897632025,
#   'rating': 4.78929503916449,
#   'reviews_count': 766,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/014/318/avatar/square_fill/1523489943-Empire-Logo.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/014/318/avatar/original/1523489943-Empire-Logo.png'},
#   'license_type': 'hybrid',
#   'address': '',
#   'distance': None,
#   'zip_code': '95430',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Now offering 10% off for all next day deliveries!\xa0</p> <p>**All minimums must be met before after discounts and before taxes**</p> <p>$3 delivery fee added to all orders under $100</p> <p>$20: Modesto</p> <p>$25: Ceres, Salida</p> <p>$30: Ripon, Manteca\xa0</p> <p>$40: French Camp, Lathrop, Turlock</p> <p>$45: Atwater, Ballico, Delhi, Escalon, Empire, Hilmar, Hughson, Keyes, Livingston, Merced, Mountain House, Oakdale, Patterson, Riverbank, Tracy, Vernallis, Waterford, Winton, Stockton, Crestley</p> <p>$100: Newman. Lodi, Gustine</p> <p>No Hotel Delivery, at this time.\xa0</p> <p>\xa0</p> <p>To order please text or email a picture of your state I.D. (and medical recommendation if under 21), delivery address, and order.</p> <p>\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/37.305433/-120.474492/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 8:00am - 10:00pm',
#   'min_age': 18,
#   'menu_items_count': 411,
#   'verified_menu_items_count': 170,
#   'endorsement_badge_count': 116,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': True},
#   'retailer_services': ['delivery']},
#  {'id': 20544,
#   'name': 'The Gas Station - Clovis',
#   'slug': 'the-gas-station-fresno-2',
#   'state': 'CA',
#   'city': 'Clovis',
#   'type': 'delivery',
#   'wmid': 428011339,
#   'latitude': 36.852183,
#   'longitude': -119.729708,
#   'web_url': 'https://weedmaps.com/deliveries/the-gas-station-fresno-2',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 4.597890328528876,
#   'rating': 4.7904,
#   'reviews_count': 125,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/020/544/avatar/square_fill/1510581461-gas_station.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/020/544/avatar/original/1510581461-gas_station.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93619',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>559-981-0696</p> <p>Free gift with every order</p> <p>Instagram @GasStationFresno</p> <p>Welcome to The Gas Station - Fresno Our mission is to provide the highest quality medicine at the most competitive prices. We provide high quality indoor grown flowers, concentrates and edibles to eligible patients in the Fresno and Clovis area.</p> <p>\xa0</p> <p>Minimum order: $50</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.852183/-119.729708/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 9:00am -  9:00pm',
#   'min_age': 21,
#   'menu_items_count': 93,
#   'verified_menu_items_count': 19,
#   'endorsement_badge_count': 11,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 45204,
#   'name': 'Green Medical Express - Oakhurst',
#   'slug': 'green-medical-express-oakhurst',
#   'state': 'CA',
#   'city': 'Oakhurst',
#   'type': 'delivery',
#   'wmid': 673981130,
#   'latitude': 37.293547,
#   'longitude': -119.647938,
#   'web_url': 'https://weedmaps.com/deliveries/green-medical-express-oakhurst',
#   'package_level': 'listing_plus',
#   'feature_order': 1,
#   'ranking': 3.43421281408091,
#   'rating': 5.0,
#   'reviews_count': 6,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/045/204/avatar/square_fill/1547779666-Smoke_Brand_Logo.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/045/204/avatar/original/1547779666-Smoke_Brand_Logo.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93644',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Welcome to green medical express, your mountain area delivery. We are medicinal only, please send over a picture of your valid identification card to get started. We service Oakhurst, Bass lake, YLP, Coarsegold, Northfork and other surrounding mountain areas. The minimum delivery fee varies depending on delivery location. The minimum starts at $60.00 Give us a call for more details. Every order recieves a free gift. Have a wonderful day. we look forward to serving you.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/37.293547/-119.647938/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  7:00pm',
#   'min_age': 18,
#   'menu_items_count': 64,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 59644,
#   'name': 'MJ 13 Elevated',
#   'slug': 'mj-13-elevated',
#   'state': 'California',
#   'city': 'Fresno',
#   'type': 'dispensary',
#   'wmid': 901152889,
#   'latitude': 36.815665,
#   'longitude': -119.78232,
#   'web_url': 'https://weedmaps.com/dispensaries/mj-13-elevated',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 3.839057691254466,
#   'rating': 4.26415094339623,
#   'reviews_count': 53,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/dispensaries/000/059/644/avatar/square_fill/1540589166-profile_picture.png',
#    'original_url': 'https://images.weedmaps.com/dispensaries/000/059/644/avatar/original/1540589166-profile_picture.png'},
#   'license_type': 'medical',
#   'address': 'Please call for appointment / location',
#   'distance': None,
#   'zip_code': '93710',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>(559) 712-1516 Ask how to receive rewards donation credit of $25. We are a proffesional dispensary plus we deliver to Fresno,Clovis, Madera, Kingsburg, Selma, Fowler, Sanger, Hanford, Lemoore,Reedley as one of the most expceptional delivery services available in the Valley area. It is our mission to improve the valley quality of life by offering the finest medicine. ALL PICS are up to date and original. No fake internet cropped pics like the other guys.</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.815665/-119.78232/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 8:00am - 11:30pm',
#   'min_age': None,
#   'menu_items_count': 84,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['storefront']},
#  {'id': 57972,
#   'name': 'Have a Heart - Coalinga',
#   'slug': 'have-a-heart-coalinga',
#   'state': 'CA',
#   'city': 'Coalinga',
#   'type': 'dispensary',
#   'wmid': 395097949,
#   'latitude': 36.140457,
#   'longitude': -120.36084,
#   'web_url': 'https://weedmaps.com/dispensaries/have-a-heart-coalinga',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 3.013029629443363,
#   'rating': 3.625,
#   'reviews_count': 24,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/dispensaries/000/057/972/avatar/square_fill/1538594800-HAH-Stacked-Black.png',
#    'original_url': 'https://images.weedmaps.com/dispensaries/000/057/972/avatar/original/1538594800-HAH-Stacked-Black.png'},
#   'license_type': 'hybrid',
#   'address': '286 N. 5th St.',
#   'distance': None,
#   'zip_code': '93210',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Our first storefront in California is now open for business!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.140457/-120.36084/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 8:00am -  9:00pm',
#   'min_age': 21,
#   'menu_items_count': 321,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['storefront']},
#  {'id': 8209,
#   'name': 'CoExist RX',
#   'slug': 'coexist-rx-2-2',
#   'state': 'CA',
#   'city': 'Arroyo Grande,',
#   'type': 'delivery',
#   'wmid': 246660192,
#   'latitude': 35.116552,
#   'longitude': -120.591838,
#   'web_url': 'https://weedmaps.com/deliveries/coexist-rx-2-2',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 4.662954403682599,
#   'rating': 4.90632911392405,
#   'reviews_count': 79,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/008/209/avatar/square_fill/1510580906-1506140023-FullSizeRender__8_.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/008/209/avatar/original/1510580906-1506140023-FullSizeRender__8_.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93436',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p><strong>THURSDAY JAN 24TH SPECIALS!</strong></p> <p><strong>BRASS KNUCKLES TAHOE OG (INDICA) $40 / 1G CARTRIDGE</strong></p> <p><strong>BRASS KNUCKLES MAUI WOWI (SATIVA) $40 / 1G CARTRIDGE</strong></p> <p><strong>BUY 1, GET 1 FREE 300MG BROWNIE</strong></p> <p><strong>25% OFF TRIPPY STICKS (NOW $15 EA)</strong></p> <p>\xa0</p> <p>TOP SHELF BLOW OUT!</p> <p>INDOOR SOUR KUSH (SATIVA) $200 OZ</p> <p>INDOOR THE WHITE (INDICA) $200 OZ</p> <p>\xa0</p> <p>NEW RELEASE -\xa0<strong>COEXIST ALIEN MOONROCKS</strong>\xa0INTRODUCTORY PRICES</p> <p>$25 / G | $85 1/8</p> <p>\xa0</p> <p>NEW RELEASE .5G\xa0<strong>MAGIC PIPE DISPOSABLE</strong>\xa0VAPE PEN\xa0</p> <p
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/35.116552/-120.591838/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  8:00pm',
#   'min_age': 18,
#   'menu_items_count': 114,
#   'verified_menu_items_count': 18,
#   'endorsement_badge_count': 5,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 14319,
#   'name': 'Empire powered by Safe Access',
#   'slug': 'safe-access-2-7',
#   'state': 'CA',
#   'city': 'Merced',
#   'type': 'delivery',
#   'wmid': 215263076,
#   'latitude': 37.346431,
#   'longitude': -120.613775,
#   'web_url': 'https://weedmaps.com/deliveries/safe-access-2-7',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 4.62461850902269,
#   'rating': 4.77869822485207,
#   'reviews_count': 169,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/014/319/avatar/square_fill/1523489960-Empire-Logo.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/014/319/avatar/original/1523489960-Empire-Logo.png'},
#   'license_type': 'hybrid',
#   'address': '',
#   'distance': None,
#   'zip_code': '95430',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Now offering 10% off for all next day deliveries!\xa0</p> <p>**All minimums must be met before after discounts and before taxes**</p> <p>$3 delivery fee added to all orders under $100</p> <p>$20: Modesto</p> <p>$25: Ceres, Salida</p> <p>$30: Ripon, Manteca\xa0</p> <p>$40: French Camp, Lathrop, Turlock</p> <p>$45: Atwater, Ballico, Delhi, Escalon, Empire, Hilmar, Hughson, Keyes, Livingston, Merced, Mountain House, Oakdale, Patterson, Riverbank, Tracy, Vernallis, Waterford, Winton, Stockton, Crestley</p> <p>$100: Newman, Lodi, Gustine</p> <p>No Hotel Delivery, at this time.\xa0</p> <p>\xa0</p> <p>\xa0</p> <p>To order please text or email a picture of your state I.D. (and medical recommendation if under 21), delivery address, and order.</p> <p>\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/37.346431/-120.613775/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 8:00am - 10:00pm',
#   'min_age': 18,
#   'menu_items_count': 411,
#   'verified_menu_items_count': 170,
#   'endorsement_badge_count': 116,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': True},
#   'retailer_services': ['delivery']},
#  {'id': 12133,
#   'name': 'Young Power 420 - Fresno',
#   'slug': 'young-power-420',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 550564884,
#   'latitude': 36.78664,
#   'longitude': -119.79074,
#   'web_url': 'https://weedmaps.com/deliveries/young-power-420',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 4.31856777246538,
#   'rating': 4.41814946619217,
#   'reviews_count': 585,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/012/133/avatar/square_fill/1510581073-18194633_161646517699790_2654606821155577167_n.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/012/133/avatar/original/1510581073-18194633_161646517699790_2654606821155577167_n.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93726',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Young Power 420 is local non-profit health organization helping patients, to collectives, to dispensaries and farms.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.78664/-119.79074/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 9:00am -  3:00am',
#   'min_age': 18,
#   'menu_items_count': 142,
#   'verified_menu_items_count': 45,
#   'endorsement_badge_count': 37,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 23047,
#   'name': 'MJ 13 Delivery',
#   'slug': 'mj-13-delivery',
#   'state': 'CALIFORNIA',
#   'city': 'Clovis',
#   'type': 'delivery',
#   'wmid': 944243953,
#   'latitude': 36.808526,
#   'longitude': -119.727214,
#   'web_url': 'https://weedmaps.com/deliveries/mj-13-delivery',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 3.712507707866151,
#   'rating': 4.14444444444444,
#   'reviews_count': 54,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/023/047/avatar/square_fill/1540603038-profile_picture.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/023/047/avatar/original/1540603038-profile_picture.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '92561',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>(559) 712-1516 Ask how to receive rewards donation credit of $25. We are a proffesional dispensary and we deliver to Fresno, Clovis, Madera, Kingsburg, Selma, Fowler, oakhurst, coarsegold, hanford, Lemmore, Kerman, Reedley as one of the most expceptional delivery services available in the Valley area. It is our mission to improve the valley quality of life by offering the finest medicine. ALL PICS are up to date and original. No fake cropped internet pics like the other guys.</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.808526/-119.727214/402/147/map.png',
#   'open_now': True,
#   'closes_in': 1156,
#   'todays_hours_str': ' 5:00am -  2:00am',
#   'min_age': 18,
#   'menu_items_count': 84,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 44906,
#   'name': 'The Higher Collection',
#   'slug': 'the-higher-collection-12',
#   'state': 'California',
#   'city': 'Santa Maria',
#   'type': 'delivery',
#   'wmid': 896133965,
#   'latitude': 34.945835,
#   'longitude': -120.431422,
#   'web_url': 'https://weedmaps.com/deliveries/the-higher-collection-12',
#   'package_level': 'listing_plus',
#   'feature_order': 2,
#   'ranking': 3.29643763602649,
#   'rating': 5.0,
#   'reviews_count': 5,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/044/906/avatar/square_fill/1544647074-Higher_Collection_Logo_black_on_white.jpeg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/044/906/avatar/original/1544647074-Higher_Collection_Logo_black_on_white.jpeg'},
#   'license_type': 'hybrid',
#   'address': '',
#   'distance': None,
#   'zip_code': '93454',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/34.945835/-120.431422/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am - 10:00pm',
#   'min_age': None,
#   'menu_items_count': 17,
#   'verified_menu_items_count': 4,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 901,
#   'name': 'Hempceuticals',
#   'slug': 'hempseuticals',
#   'state': 'California',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 199679357,
#   'latitude': 36.837257,
#   'longitude': -119.826278,
#   'web_url': 'https://weedmaps.com/deliveries/hempseuticals',
#   'package_level': 'listing_plus',
#   'feature_order': 3,
#   'ranking': 4.73721012887682,
#   'rating': 4.78734622144113,
#   'reviews_count': 569,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/000/901/avatar/square_fill/1510580593-hemplogo.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/000/901/avatar/original/1510580593-hemplogo.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93711',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Currently only accepting Valid Medical Patients! Hempceuticals is open 7 days a week providing quality meds, concentrates and edibles in the Fresno and Clovis areas. We are compassionate, caring, prompt, and friendly. Why wait? We are accepting new patients call us today and schedule same day delivery!!!! We offer a wide selection of cannabis, concentrates, vape THC and CBD cartridges, tinctures, and edibles with prices to fit most any medicinal budget! Patient Satisfaction is our #1 Priority!\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.837257/-119.826278/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  8:00pm',
#   'min_age': 18,
#   'menu_items_count': 418,
#   'verified_menu_items_count': 216,
#   'endorsement_badge_count': 195,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 9937,
#   'name': 'DabLife805 - 5 Cities and SLO',
#   'slug': 'dablife805-2',
#   'state': 'CA',
#   'city': 'Oceano',
#   'type': 'delivery',
#   'wmid': 233955452,
#   'latitude': 35.09917,
#   'longitude': -120.61247,
#   'web_url': 'https://weedmaps.com/deliveries/dablife805-2',
#   'package_level': 'listing_plus',
#   'feature_order': 3,
#   'ranking': 4.486340864300459,
#   'rating': 4.98709677419355,
#   'reviews_count': 31,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/009/937/avatar/square_fill/1510580974-DabLife805.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/009/937/avatar/original/1510580974-DabLife805.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93445',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': "<p>Patients with questions and delivery requests can contact us by phone or via text (805) 503-0755.</p> <p>\xa0</p> <p><strong>To better serve you and improve our delivery service, please take this short 2 min survey:</strong></p> <p>https://www.surveymonkey.com/r/WNSZQXD or Click our Facebook Link.</p> <p>\xa0</p> <p><strong>DabLife805 is the Premier Medical Marijuana Delivery Service in San Luis Obispo</strong></p> <p>DabLife805 offers a reliable delivery service that caters to patients in the cannabis communities surrounding San Luis Obispo. Our team is comprised of real caring people, passionate about providing our patients with superior meds and exceptional personal services. DabLife805 operates in full compliance with California Proposition 215 and Senate Bill 420. We strive to bring our patients an assortment of the highest quality medical cannabis at the most affordable prices.</p> <p>\xa0</p> <p><strong>Our Team, Culture, and Commitment\xa0</strong></p> <p>At DabLife805 we pride ourselves on our tireless efforts in providing operational efficiency and doing so with the utmost professionalism. Our entire team, every individual from our office staff to our delivery representatives, has been carefully selected because each one exemplifies our undying committment to our patients. We set the bar high in patient satisfaction because we wouldn't accept anything less for ourselves. Our goal is to get you what you need promptly, from the people you can trust and depend on. Welcome to our collective and the DabLife805 family.</p> <p>\xa0</p>",
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/35.09917/-120.61247/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am - 10:00pm',
#   'min_age': 18,
#   'menu_items_count': 98,
#   'verified_menu_items_count': 58,
#   'endorsement_badge_count': 8,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 3521,
#   'name': 'Mr. 805 Organics',
#   'slug': 'mr-805-organics',
#   'state': 'CA',
#   'city': 'Santa Maria',
#   'type': 'delivery',
#   'wmid': 978467449,
#   'latitude': 34.955418,
#   'longitude': -120.430219,
#   'web_url': 'https://weedmaps.com/deliveries/mr-805-organics',
#   'package_level': 'listing_plus',
#   'feature_order': 3,
#   'ranking': 4.359372380656195,
#   'rating': 4.58558558558559,
#   'reviews_count': 111,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/003/521/avatar/square_fill/1510580689-IMG_7029.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/003/521/avatar/original/1510580689-IMG_7029.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93458',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>MR. 805 ORGANCIS SERVES THE CITIES OF ORCUTT, SANTA MARIA, GUADALUPE, AND NIPOMO. WE DO NOT DELIVER FURTHER THAN NIPOMO, OR LOWER THEN ORCUTT. $25 MINIMUM FOR DELIVERY.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/34.955418/-120.430219/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am - 10:00pm',
#   'min_age': 21,
#   'menu_items_count': 22,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 50920,
#   'name': 'Cafe 710',
#   'slug': 'buds-4-life-2-o',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'dispensary',
#   'wmid': 216538796,
#   'latitude': 36.836431,
#   'longitude': -119.912347,
#   'web_url': 'https://weedmaps.com/dispensaries/buds-4-life-2-o',
#   'package_level': 'listing_plus',
#   'feature_order': 4,
#   'ranking': 4.6159262581087,
#   'rating': 4.73618677042801,
#   'reviews_count': 257,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/dispensaries/000/050/920/avatar/square_fill/1530646752-cafe710.jpg',
#    'original_url': 'https://images.weedmaps.com/dispensaries/000/050/920/avatar/original/1530646752-cafe710.jpg'},
#   'license_type': 'medical',
#   'address': '**Call for verification**',
#   'distance': None,
#   'zip_code': '93722',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Delivery only for first time patients.\xa0</p> <p>\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.836431/-119.912347/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  7:00pm',
#   'min_age': 21,
#   'menu_items_count': 106,
#   'verified_menu_items_count': 36,
#   'endorsement_badge_count': 22,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['storefront']},
#  {'id': 33849,
#   'name': '559 Flowerz',
#   'slug': '559-flowerz',
#   'state': 'CA',
#   'city': 'Clovis/Fresno',
#   'type': 'delivery',
#   'wmid': 385547927,
#   'latitude': 36.851963,
#   'longitude': -119.756711,
#   'web_url': 'https://weedmaps.com/deliveries/559-flowerz',
#   'package_level': 'listing_plus',
#   'feature_order': 4,
#   'ranking': 4.471093647526246,
#   'rating': 4.85,
#   'reviews_count': 48,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/033/849/avatar/square_fill/1522868335-8675779F-E34B-475B-80C4-E68E067D53FC.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/033/849/avatar/original/1522868335-8675779F-E34B-475B-80C4-E68E067D53FC.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93720',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>559 Flowerz specializes in locally cultivated, organically grown flowers & concentrates. Sourced directly from the heart of the Sierra Nevadas, 559 flowerz strives to connect great medicine with good people. Home of the Best $100 Oz in the Valley. We are a Farm to Table delivery, servicing all of Fresno and CLovis. Do you know where your cannabis comes from? to learn more about how we cultivate follow our instagram for daily updates and farming information.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.851963/-119.756711/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 2:00pm -  8:00pm',
#   'min_age': 21,
#   'menu_items_count': 19,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 26916,
#   'name': 'Central Valley Green',
#   'slug': 'central-valley-green',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 820779870,
#   'latitude': 36.822772,
#   'longitude': -119.826354,
#   'web_url': 'https://weedmaps.com/deliveries/central-valley-green',
#   'package_level': 'listing_plus',
#   'feature_order': 4,
#   'ranking': 4.419690676955476,
#   'rating': 4.60348837209302,
#   'reviews_count': 172,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/026/916/avatar/square_fill/1518475750-1510581765-1504826617-cvgc.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/026/916/avatar/original/1518475750-1510581765-1504826617-cvgc.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93650',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>**WELCOME TO CENTRAL VALLEY GREEN ***</p> <p>**BRINGING YOU THE FINEST SELECTION OF FLOWERS IN THE CENTRAL VALLEY**</p> <p>ALL TOP SHELF $100 A HALF 14G *ANY 4 1/8THS FOR A $100</p> <p>We are a non profit medical marijuana delivery service specializing in quality top shelf meds delivered.</p> <p>*MINIMUM $40 DONATION IN FRESNO</p> <p>*MINIMUM $100 OUT OF TOWN DONATION*</p> <p>*MINIMUM $50.00 AFTER 9:00 PM</p> <p>DELIVERING TOP SHELF MEDS TO FRESNO AND SURROUNDING AREAS\xa0</p> <p><br>\xa0<br>**FIRST TIME PATIENTS RECEIVE A FREE PREROLL!!!!! CALL TODAY!!!**<br>**Simply text a picture of your valid CALIFORNIA I.D. & DR RECOMMENDATION to 559-578-7904 or email us at cvgcfresno@gmail.com to become a verified patient**<br>**VERIFIED IN 15 MINS**<br>**NO DELIVERY CHARGE**<br>**CASH ONLY**<br>**ALL SALES ARE FINAL NO REFUNDS OR EXCHANGES**</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.822772/-119.826354/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  9:50pm',
#   'min_age': 18,
#   'menu_items_count': 146,
#   'verified_menu_items_count': 27,
#   'endorsement_badge_count': 27,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 56852,
#   'name': 'Mile High Dispensary, LLC',
#   'slug': 'mile-high-dispensary-llc',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'dispensary',
#   'wmid': 345858994,
#   'latitude': 36.728739,
#   'longitude': -119.780377,
#   'web_url': 'https://weedmaps.com/dispensaries/mile-high-dispensary-llc',
#   'package_level': 'listing_plus',
#   'feature_order': 5,
#   'ranking': 3.88215666984119,
#   'rating': 4.63157894736842,
#   'reviews_count': 19,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/dispensaries/000/056/852/avatar/square_fill/1538166730-milehighlogo.png',
#    'original_url': 'https://images.weedmaps.com/dispensaries/000/056/852/avatar/original/1538166730-milehighlogo.png'},
#   'license_type': 'medical',
#   'address': 'By appointment only',
#   'distance': None,
#   'zip_code': '93721',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>**\xa0</p> <p>Greetings!\xa0\xa0Follow us on Instagram @mhighdispensary or SnapChat @milehigh559 and receive 5% off when you show your budtender! Here at Mile High, we are a mom and pop, female Native American owned dispensary. We are excited to announce that we are a new dispensary in Fresno, and we would love the opportunity to serve you and your medical needs in a discreet and professional manner. Please call for verification; storefront is by appointment only. We guarantee your complete satisfaction.\xa0\xa0</p> <p>You can also text in your information to (559) 307-6660 to get verified and set your appointment!\xa0</p> <p>**Be sure to check our sidebar announcements as those are updated frequently!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.728739/-119.780377/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '11:00am -  7:00pm',
#   'min_age': 18,
#   'menu_items_count': 42,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['storefront']},
#  {'id': 214,
#   'name': 'Bat Buds Collective - Fresno, Clovis',
#   'slug': 'bat-buds-collective',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 478992699,
#   'latitude': 36.805992,
#   'longitude': -119.846682,
#   'web_url': 'https://weedmaps.com/deliveries/bat-buds-collective',
#   'package_level': 'listing_plus',
#   'feature_order': 5,
#   'ranking': 4.5012763790413,
#   'rating': 4.59806451612903,
#   'reviews_count': 310,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/000/214/avatar/square_fill/1510580498-bbhow.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/000/214/avatar/original/1510580498-bbhow.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93722',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>\xa0Unfortunately we are temporarily going to suspend business as prop 215 expires on January 10th 2019. Local authority have had two years to accomplish clear guidelines and have failed us the people, their constituents. Please keep this in consideration the next time you visit the polls. Thank you for your support and we look forward to providing you with the best possible service when we are fully liscenced and compliant.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.805992/-119.846682/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': 'Closed',
#   'min_age': 21,
#   'menu_items_count': 65,
#   'verified_menu_items_count': 2,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 40610,
#   'name': 'Medallion Wellness Delivery - Merced',
#   'slug': 'medallion-wellness-delivery-merced',
#   'state': 'CA',
#   'city': 'Merced',
#   'type': 'delivery',
#   'wmid': 955483746,
#   'latitude': 37.297693,
#   'longitude': -120.476418,
#   'web_url': 'https://weedmaps.com/deliveries/medallion-wellness-delivery-merced',
#   'package_level': 'listing_plus',
#   'feature_order': 5,
#   'ranking': 4.15344624429862,
#   'rating': 4.7,
#   'reviews_count': 30,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/040/610/avatar/square_fill/1533610675-Medallion_Wellness_Logo.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/040/610/avatar/original/1533610675-Medallion_Wellness_Logo.jpg'},
#   'license_type': 'hybrid',
#   'address': '',
#   'distance': None,
#   'zip_code': '95340',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>At Medallion, we only serve our patients the highest quality medicinal & recreational cannabis products on the market. We take great pride in our knowledgeable friendly staff and we understand products work different for individual needs. We are here to help you find your perfect medicine on your path to Wellness!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/37.297693/-120.476418/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
# ...
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/34.953604/-120.453703/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': 'Closed',
#   'min_age': 18,
#   'menu_items_count': 121,
#   'verified_menu_items_count': 35,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 21899,
#   'name': "D's Kana Bus",
#   'slug': 'd-s-canna-bus',
#   'state': 'Ca',
#   'city': 'Taft',
#   'type': 'delivery',
#   'wmid': 560118957,
#   'latitude': 35.140706,
#   'longitude': -119.451441,
#   'web_url': 'https://weedmaps.com/deliveries/d-s-canna-bus',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.85136685833159,
#   'rating': 4.75714285714286,
#   'reviews_count': 14,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/021/899/avatar/square_fill/1510581462-FullSizeRender-1.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/021/899/avatar/original/1510581462-FullSizeRender-1.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93268',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0CALL US NOW!!!!!!\xa0 \xa0661-623-2827</p> <p>Delivering HIGH quality buds, wax, and cartridges near you!!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/35.140706/-119.451441/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am -  7:00pm',
#   'min_age': 18,
#   'menu_items_count': 34,
#   'verified_menu_items_count': 6,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 27498,
#   'name': 'Tiny Weeds',
#   'slug': 'tiny-weeds',
#   'state': 'CA',
#   'city': 'Clovis',
#   'type': 'delivery',
#   'wmid': 635996535,
#   'latitude': 36.823016,
#   'longitude': -119.71889,
#   'web_url': 'https://weedmaps.com/deliveries/tiny-weeds',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.824193406461474,
#   'rating': 4.0624203821656,
#   'reviews_count': 157,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/027/498/avatar/square_fill/1510581719-1505930195-large_1505879958-Tiny_Weeds.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/027/498/avatar/original/1510581719-1505930195-large_1505879958-Tiny_Weeds.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93611',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>REQUEST A DIPPED PREROLL WITH ANY ORDER OVER $100..3X CRAZY INDOOR $150 OZ...WAKE N BAKE $30 MINIMUM 6AM-1PM + A PREROLL!!! A FREE PREROLL; EDIBLE or PREROLL WITH ANY 45 MINUMUM 60 after 11PM. TINY WEEDS offers HIGH QUALITY TOP-SHELF MEDICAL CANNABIS to all verified Prop 215. Patients. 24/7 UPOND REQUEST to meet our patients needs. For verification please TXT THE NUMBER PROVIDED\xa0 ( will need copy of your recommendation letter and California ID )\xa0All Meds are 100% patient satisfaction feel free to MIX and MATCH (same or less value not on sale items) in every order we will add a FREE PRE-ROLL or EDIBLE for you to enjoy . YES with EVERY ORDER!!! If you have any special request or recommendation to better our service please let us know we are here to provide the best service possible FOR YOU!!!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.823016/-119.71889/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 7:00am -  2:00am',
#   'min_age': 18,
#   'menu_items_count': 298,
#   'verified_menu_items_count': 4,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 9110,
#   'name': '24/7 Heaven',
#   'slug': '24-7-heaven',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 988470070,
#   'latitude': 36.852193,
#   'longitude': -119.791019,
#   'web_url': 'https://weedmaps.com/deliveries/24-7-heaven',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.80631602275077,
#   'rating': 4.02994011976048,
#   'reviews_count': 167,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/009/110/avatar/square_fill/1510580941-247-instagram.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/009/110/avatar/original/1510580941-247-instagram.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93711',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>We love our members in the Central Valley. Thanks for making us so welcome!! Minimum delivery order: $50 donation FREE edible & generic pre-roll with every order, as supplies allow. Call/text to verify. Prop 215 patients only. If you need change made, please notify us when you place your order.\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.852193/-119.791019/402/147/map.png',
#   'open_now': True,
#   'closes_in': 1295,
#   'todays_hours_str': ' 4:20am -  4:19am',
#   'min_age': None,
#   'menu_items_count': 259,
#   'verified_menu_items_count': 90,
#   'endorsement_badge_count': 83,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 8316,
#   'name': 'Go Green Care - Santa Maria',
#   'slug': 'go-green-care-2-2',
#   'state': 'CA',
#   'city': 'Santa Maria',
#   'type': 'delivery',
#   'wmid': 745043269,
#   'latitude': 34.967801,
#   'longitude': -120.444612,
#   'web_url': 'https://weedmaps.com/deliveries/go-green-care-2-2',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.724123164891027,
#   'rating': 4.45,
#   'reviews_count': 20,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/008/316/avatar/square_fill/1510580914-Go_Green_Care_logo.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/008/316/avatar/original/1510580914-Go_Green_Care_logo.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93458',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Serving the Central Coast (San Luis Obispo & Santa Barbara Counties) since 2008. All patients receive 2 FREE gifts on EVERY delivery of $50 or more. NEW PATIENTS receive a First-Time Goodie Bag with minimum order. Includes Various flower and a handful of other treats!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/34.967801/-120.444612/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 9:00am - 10:00pm',
#   'min_age': 18,
#   'menu_items_count': 72,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 45650,
#   'name': 'Maryjane 559',
#   'slug': 'maryjane-559-2',
#   'state': 'California',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 202251298,
#   'latitude': 36.855973,
#   'longitude': -119.7873,
#   'web_url': 'https://weedmaps.com/deliveries/maryjane-559-2',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.43421281408091,
#   'rating': 5.0,
#   'reviews_count': 6,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/045/650/avatar/square_fill/1547371941-Screenshot_20190113-012817_1_.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/045/650/avatar/original/1547371941-Screenshot_20190113-012817_1_.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93720',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>WELCOME!! We are new to Fresno region and here to service you with fresh, new, topshelf clean meds!! Come join the Maryjane 559 collective where we strive to provide excellent customer service & topshelf meds for affordable prices. Thank you for taking the time to visit our page and feel free to give suggestions to us to better YOUR service ; ) ALL FLOWERS ARE INDOOR!!</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.855973/-119.7873/402/147/map.png',
#   'open_now': True,
#   'closes_in': 76,
#   'todays_hours_str': 'All Day',
#   'min_age': 21,
#   'menu_items_count': 26,
#   'verified_menu_items_count': 17,
#   'endorsement_badge_count': 12,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 40157,
#   'name': '911 Emergency Medical Marijuana Delivery',
#   'slug': '911-emergency-medical-marijuana-delivery',
#   'state': 'California',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 220931901,
#   'latitude': 36.758489,
#   'longitude': -119.81849,
#   'web_url': 'https://weedmaps.com/deliveries/911-emergency-medical-marijuana-delivery',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.394863534219621,
#   'rating': 4.13,
#   'reviews_count': 20,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/040/157/avatar/square_fill/1533337451-the_green_house_collective_finished_logo_10-23-17.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/040/157/avatar/original/1533337451-the_green_house_collective_finished_logo_10-23-17.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93744',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Hello</p> <p>welcome\xa0 to our collective. Thank you for visiting our web page site.\xa0 Please take a moment to look our menu over.After you have decided on your items, text over your Medical Recommendation and Identification information for verification. Also send your delivery address, so that we can provide you an ETA for your delivery.</p> <p>Each Delivery is Estimated 45 - 60 minutes.</p> <p>\xa0Text:\xa0 559 217-7115\xa0</p> <p>Minimum Delivery is:\xa0 \xa0</p> <p>35.00 From\xa0 7am - 12am /85 after 12am.-6:30am</p> <p><strong>-911EMMDT</strong></p> <p>\xa0</p> <p>\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.758489/-119.81849/402/147/map.png',
#   'open_now': True,
#   'closes_in': 1036,
#   'todays_hours_str': 'All Day',
#   'min_age': 18,
#   'menu_items_count': 17,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 41863,
#   'name': 'ganjarunner',
#   'slug': 'ganjarunner-14',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 904485868,
#   'latitude': 36.852084,
#   'longitude': -119.747788,
#   'web_url': 'https://weedmaps.com/deliveries/ganjarunner-14',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.27277682207181,
#   'rating': 4.25,
#   'reviews_count': 12,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/041/863/avatar/square_fill/1536716262-GanjaGuyFB.jpg',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/041/863/avatar/original/1536716262-GanjaGuyFB.jpg'},
#   'license_type': 'hybrid',
#   'address': '',
#   'distance': None,
#   'zip_code': '93720',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>\xa0NEXT-DAY MEDICINAL AND RECREATIONAL CANNABIS DELIVERY! Visit ganjarunner.com to sign up and browse our extensive collection of premium cannabis products. Save 10% on your first order and receive an official Ganjarunner Starter Kit with coupon code: elevate \xa0*(Offer cannot be used with other coupons and cannot be applied to items that are already on sale or discounted)</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.852084/-119.747788/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:00am - 10:00pm',
#   'min_age': 18,
#   'menu_items_count': 273,
#   'verified_menu_items_count': 172,
#   'endorsement_badge_count': 133,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 43876,
#   'name': 'Cali Plug',
#   'slug': 'cali-plug',
#   'state': 'California',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 302491238,
#   'latitude': 36.769276,
#   'longitude': -119.759237,
#   'web_url': 'https://weedmaps.com/deliveries/cali-plug',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.21593067601676,
#   'rating': 4.33333333333333,
#   'reviews_count': 9,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/square_fill/image_missing.jpg',
#    'original_url': 'https://images.weedmaps.com/original/image_missing.jpg'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93705',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>Welcome to Cali Plug. Our menu will remain small but change frequently. Serving the Fresno area with high quality meds for those on a budget. We only carry Indoor meds.</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.769276/-119.759237/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': '10:30am -  6:00pm',
#   'min_age': None,
#   'menu_items_count': 5,
#   'verified_menu_items_count': 0,
#   'endorsement_badge_count': 0,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']},
#  {'id': 43113,
#   'name': 'Bear Mountain Collective',
#   'slug': 'bear-mountain-collective-2',
#   'state': 'CA',
#   'city': 'Fresno',
#   'type': 'delivery',
#   'wmid': 745534077,
#   'latitude': 36.794015,
#   'longitude': -119.853411,
#   'web_url': 'https://weedmaps.com/deliveries/bear-mountain-collective-2',
#   'package_level': 'basic',
#   'feature_order': 9999,
#   'ranking': 3.15515426579497,
#   'rating': 3.75862068965517,
#   'reviews_count': 29,
#   'avatar_image': {'small_url': 'https://images.weedmaps.com/deliveries/000/043/113/avatar/square_fill/1545972591-bearmt.png',
#    'original_url': 'https://images.weedmaps.com/deliveries/000/043/113/avatar/original/1545972591-bearmt.png'},
#   'license_type': 'medical',
#   'address': '',
#   'distance': None,
#   'zip_code': '93722',
#   'timezone': 'America/Los_Angeles',
#   'intro_body': '<p>BE SURE TO CHECK THE MENU ITEMS BEFORE PLACING AN ORDER TO SEE WHAT IS INSTOCK. \xa0We are currently accepting new patients, please send picture of valid CA ID or DL, along with valid rec to (559) 554-5350.\xa0 FOR PATIENTS BY PATIENTS but place a high importance on our drivers safety so please be curtosy and responsive when drivers arrives, also we will not provide service if we are unable to verify a recommendation and ID; it is beyond our control if we are unable to verify.\xa0 Please do not ask for our deals if they are not posted, as that would be unfair to all the other patients.\xa0 Any questions and concerns may be submitted to our email and we are more than happy to respond in a timely manner.</p> <p>*Be sure to check out the deals page for both Fresno and Clovis as each city has a different deal every 24 hours.\xa0</p> <p>\xa0</p> <p>*Must mention the below specials:</p> <p>1. 5 for 75 mix and match between any of our wax, excluding BARE products</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p>',
#   'static_map_url': 'https://staticmap.weedmaps.com/static_map/13/36.794015/-119.853411/402/147/map.png',
#   'open_now': False,
#   'closes_in': None,
#   'todays_hours_str': ' 9:30am - 11:30pm',
#   'min_age': None,
#   'menu_items_count': 24,
#   'verified_menu_items_count': 3,
#   'endorsement_badge_count': 3,
#   'is_published': True,
#   'online_ordering': {'enabled_for_pickup': False,
#    'enabled_for_delivery': False},
#   'retailer_services': ['delivery']}]

# %%
[x["retailer_services"] for x in tmp["data"]["listings"]]
# Out:
# [['storefront'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['storefront'],
#  ['storefront'],
#  ['storefront'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery'],
#  ['delivery']]
