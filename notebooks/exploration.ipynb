# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
glob.glob("..//data//*")
# Out:
# ['..//data\\ReocrdList20190116.csv', '..//data\\searchResults.csv']

# %%
calcannabis = pd.read_csv("..//data//ReocrdList20190116.csv", encoding = "utf-8")

# %%
calcannabis.head()
# Out:
#   License Number                            License Type  \
# 0  CML18-0000017  Medicinal Cannabis Cultivation License
# 1  CAL18-0000016  Adult-Use Cannabis Cultivation License
# 2  CAL18-0000724  Adult-Use Cannabis Cultivation License
# 3  CAL18-0000086  Adult-Use Cannabis Cultivation License
# 4  TAL18-0016768  Temporary Cannabis Cultivation License
#
#            Legal Business Name                       Type of License  \
# 0  Willow Creekside Farms Inc.                         Small Outdoor
# 1   Willow Creekside Farms Inc  Specialty Cottage Mixed-Light Tier 2
# 2           SBM Associates LLC                      Specialty Indoor
# 3           Humboldt Edge Farm              Small Mixed-Light Tier 1
# 4        Long Creek Ranch, LLC                     Specialty Outdoor
#
#          Date  Expires On  Status                      City - County  \
# 0  01/04/2019  01/04/2020  Active     Willow Creek - Humboldt County
# ...

# %%
bcc = pd.read_csv("..//data//searchResults.csv", encoding = "utf-8")

# %%
bcc.loc[0]["Business Contact Information"]
# Out:
# 'MOVOCAN : Email- medigroupangel@gmail.com : Phone- 7605409358 : Website- www.movocan.com'

# %%
bcc.loc[0]["Premise Address"]
# Out:
# 'CALEXICO, CA 922319530 County: IMPERIAL '

# %%
bcc[bcc["License Type"] == "Cannabis - Retailer License"]
# Out:
#        License Number                 License Type  \
# 1514  C10-0000006-LIC  Cannabis - Retailer License
# 1525  C10-0000007-LIC  Cannabis - Retailer License
# 1526  C10-0000008-LIC  Cannabis - Retailer License
# 1581  C10-0000005-LIC  Cannabis - Retailer License
# 1601  C10-0000004-LIC  Cannabis - Retailer License
# 1622  C10-0000003-LIC  Cannabis - Retailer License
# 1634  C10-0000002-LIC  Cannabis - Retailer License
# 1648  C10-0000001-LIC  Cannabis - Retailer License
#
#                                          Business Owner  \
# 1514                         Robert Tatum: Robert Tatum
# 1525  Raphael Calderon: Conrad Bonet Jr: Raphael Cal...
# 1526                     Jeffery Angell: Jeffery Angell
# 1581                       Robert Watson: Robert Watson
# 1601                           Kort Potter: Kort Potter
# 1622                 Gayk Akhsharumov: Gayk Akhsharumov
# 1634                           Eric Thomas: Eric Thomas
# ...

# %%
bcc[bcc["License Type"] == "Cannabis - Retailer Temporary License"]
# Out:
#            License Number                           License Type  \
# 1     C10-18-0000287-TEMP  Cannabis - Retailer Temporary License
# 7     C10-18-0000288-TEMP  Cannabis - Retailer Temporary License
# 23    C10-18-0000289-TEMP  Cannabis - Retailer Temporary License
# 37    C10-18-0000290-TEMP  Cannabis - Retailer Temporary License
# 49    C10-18-0000291-TEMP  Cannabis - Retailer Temporary License
# 52    C10-18-0000292-TEMP  Cannabis - Retailer Temporary License
# 63    C10-18-0000293-TEMP  Cannabis - Retailer Temporary License
# 75    C10-18-0000294-TEMP  Cannabis - Retailer Temporary License
# 78    C10-18-0000295-TEMP  Cannabis - Retailer Temporary License
# 96    C10-18-0000285-TEMP  Cannabis - Retailer Temporary License
# 98    C10-18-0000286-TEMP  Cannabis - Retailer Temporary License
# 110   C10-18-0000278-TEMP  Cannabis - Retailer Temporary License
# 111   C10-18-0000279-TEMP  Cannabis - Retailer Temporary License
# ...

# %%
bcc[bcc["License Type"] == "Cannabis - Retailer Temporary License"].loc[1]["Premise Address"]
# Out:
# '1632 GATEWAY RD CALEXICO, CA 922319530 County: IMPERIAL'

# %%
bcc.loc[
# Out:
# License Number                                                C11-18-0000939-TEMP
# License Type                             Cannabis - Distributor Temporary License
# Business Owner                                                    Angel Fernandez
# Business Contact Information    MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# Business Structure                                                    Corporation
# Premise Address                          CALEXICO, CA 922319530 County: IMPERIAL
# Status                                                                     Active
# Issue Date                                                             07/29/2019
# Expiration Date                                                        12/31/2018
# Activities                                              N/A for this license type
# Adult-Use/Medicinal                                                          BOTH
# Name: 0, dtype: object

# %%
calcannabis["License Type"].unique()
# Out:
# array(['Medicinal Cannabis Cultivation License',
#        'Adult-Use Cannabis Cultivation License',
#        'Temporary Cannabis Cultivation License'], dtype=object)

# %%
bcc["License Type"].unique()
# Out:
# array(['Cannabis - Distributor Temporary License',
#        'Cannabis - Retailer Temporary License',
#        'Cannabis - Retailer Nonstorefront Temporary License',
#        'Cannabis - Microbusiness Temporary License',
#        'Cannabis - Distributor-Transport Only Temporary License',
#        'Cannabis - Event Organizer Temporary License', 'License Type',
#        'Cannabis - Testing Laboratory Temporary License',
#        'Cannabis - Distributor License', 'Cannabis - Retailer License',
#        'Cannabis - Event Organizer License'], dtype=object)
