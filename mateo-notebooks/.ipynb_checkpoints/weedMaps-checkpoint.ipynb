# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import os
import glob
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# ## Load Weedmaps dataframe

# %%
def load_weedmaps_df(lower_latitude, left_longitude, upper_latitude, right_longitude):
    """Returns a pandas dataframe of marijuana dispensaries within the geographical constraints
    specified in the input. Uses the Weedmaps list of marijuana retailers.
    """
    url = ("https://api-g.weedmaps.com/discovery/v1/listings?filter%"
            "5Bany_retailer_services%5D%5B%5D=doctor&filter%5Bany_retailer_services"
            "%5D%5B%5D=storefront&filter%5Bany_retailer_services%5D%5B%5D=delivery&filter%"
            "5Bbounding_box%5D={},{},{},{}"
            "&page_size=150&size=150").format(lower_latitude, left_longitude, upper_latitude, right_longitude)
    get_stores = requests.get(url, verify = False)
    stores_json = get_stores.json()
    stores_json_norm = json_normalize(stores_json.get('data', {}).get('listings', {}))
    
    weed_stores_df = pd.DataFrame(stores_json_norm)[["name", "id", "address", "city", "state", "zip_code", "latitude", 
                      "longitude", "license_type", "type", "menu_items_count", 
                      "retailer_services", "online_ordering.enabled_for_delivery", 
                      "online_ordering.enabled_for_pickup", "ranking", "rating", 
                      "reviews_count", "web_url"]]
    return weed_stores_df

# %%
weed_stores_df = load_weedmaps_df(25, - 120, 35, -100)
weed_stores_df.shape
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# (150, 18)

# %%
weed_stores_df.head()
# Out:
#                             name     id                       address  \
# 0               Ponderosa Releaf  26300  9240 W Northern Ave Ste 103B
# 1      The W 25CAP of Wilmington  46434    1302 North Wilmington Blvd
# 2  BONAFIDE COLLECTIVE - Pre ICO  21706         7570 San Fernando Rd.
# 3                      Roze City  43964       365 South Rosemead Blvd
# 4            The Mint Dispensary  50982              5210 S Priest Dr
#
#          city state zip_code   latitude   longitude  license_type        type  \
# 0    Glendale    AZ    85305  33.552681 -112.258388       medical  dispensary
# 1  Wilmington    CA    90744  33.788653 -118.274743       medical  dispensary
# 2     Burbank    CA    91504  34.209405 -118.353570  recreational  dispensary
# 3    PASADENA    CA    91107  34.140204 -118.073685  recreational  dispensary
# 4   Guadalupe    AZ    85283  33.377176 -111.963797       medical  dispensary
#
#    menu_items_count retailer_services  online_ordering.enabled_for_delivery  \
# 0               227      [storefront]                                 False
# 1               194      [storefront]                                 False
# 2               367      [storefront]                                 False
# 3               451      [storefront]                                 False
# 4               433      [storefront]                                 False
#
#    online_ordering.enabled_for_pickup   ranking    rating  reviews_count  \
# 0                                True  4.963562  4.967438           4146
# 1                               False  4.937452  4.945589           6359
# 2                               False  4.934087  4.944010           3247
# 3                               False  4.920778  4.931495           3626
# 4                               False  4.913605  4.913838           2746
#
#                                              web_url
# 0  https://weedmaps.com/dispensaries/ponderosa-re...
# 1  https://weedmaps.com/dispensaries/the-w-collec...
# 2  https://weedmaps.com/dispensaries/bonafide-gro...
# 3  https://weedmaps.com/dispensaries/nhc-natural-...
# 4  https://weedmaps.com/dispensaries/the-mint-dis...

# %% [markdown]
# ## Single Store

# %%
## Obtain products and prices from each store. 
get_store = requests.get("https://weedmaps.com/dispensaries/the-crop")
store_parsed = BeautifulSoup(get_store.content, 'lxml')
#store_json = json.loads(store_parsed.text)
#store_json

# %%
store_parsed.text
# Out:
# '{"@context":"http://schema.org","@type":"LocalBusiness","@id":"https://weedmaps.com/dispensaries/the-crop","name":"The Crop","email":"mailto:thecrop661@gmail.com","url":"","logo":"https://images.weedmaps.com/dispensaries/000/047/603/avatar/square_fill/1546807008-B60BEF19-5F08-48E1-832E-B206B990BC96.jpeg","image":"https://images.weedmaps.com/dispensaries/000/047/603/avatar/square_fill/1546807008-B60BEF19-5F08-48E1-832E-B206B990BC96.jpeg","description":"","telephone":"661-393-7342","openingHoursSpecification":[{"@type":"OpeningHoursSpecification","dayOfWeek":"sunday","opens":"10:00","closes":"20:00"},{"@type":"OpeningHoursSpecification","dayOfWeek":"monday","opens":"10:00","closes":"20:00"},{"@type":"OpeningHoursSpecification","dayOfWeek":"tuesday","opens":"10:00","closes":"20:00"},{"@type":"OpeningHoursSpecification","dayOfWeek":"wednesday","opens":"10:00","closes":"20:00"},{"@type":"OpeningHoursSpecification","dayOfWeek":"thursday","opens":"10:00","closes":"20:00"},{"@type":"OpeningHoursSpecification","dayOfWeek":"friday","opens":"10:00","closes":"20:00"},{"@type":"OpeningHoursSpecification","dayOfWeek":"saturday","opens":"10:00","closes":"20:00"}],"address":{"@type":"PostalAddress","streetAddress":"5950 State Rd","addressLocality":"Bakersfield","addressRegion":"CA","postalCode":"93308"},"geo":{"@type":"GeoCoordinates","latitude":35.414963,"longitude":-119.056766},"aggregateRating":{"@type":"AggregateRating","ratingValue":4.98643533123028,"reviewCount":3804},"priceRange":"$3 - $90"}The Crop - Bakersfield, CA Marijuana Dispensary | Weedmaps\n/* sc-component-id: sc-bdVaJa */\n.PMSob{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;border-bottom:4px solid transparent;} .PMSob > a{padding:10px 16px;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;color:#4A4A4A;font-size:14px;font-weight:600;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI","Roboto","Oxygen","Ubuntu","Cantarell","Fira Sans","Droid Sans","Helvetica Neue",sans-serif;text-transform:uppercase;line-height:17px;text-align:center;display:block;-webkit-text-decoration:none;text-decoration:none;}\n/* sc-component-id: sc-bxivhb */\n.ceYwGx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;overflow:auto;position:relative;-webkit-overflow-scrolling:touch;-ms-overflow-style:-ms-autohiding-scrollbar;}\n/* sc-component-id: top-nav__HeaderTabs-sc-5mfvrd-0 */\n.gJUOfd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;max-width:75rem;margin:0 auto;-webkit-align-items:baseline;-webkit-box-align:baseline;-ms-flex-align:baseline;align-items:baseline;padding:0 1rem;} @media only screen and (max-width:639px){.gJUOfd{padding:0;}}\n/* sc-component-id: top-nav__GlobalHeaderTab-sc-5mfvrd-1 */\n.cOAVXU{-webkit-box-flex:0 !important;-webkit-flex-grow:0 !important;-ms-flex-positive:0 !important;flex-grow:0 !important;height:3.5rem;box-sizing:border-box;display:block;} .cOAVXU .nav-links > a{font-size:0.875rem;font-family:proxima-nova,-apple-system,BlinkMacSystemFont,"Helvetica Neue",Helvetica,Roboto,Arial,sans-serif;color:#989898 !important;font-weight:normal;display:-webkit-box !important;display:-webkit-flex !important;display:-ms-flexbox !important;display:flex !important;margin-bottom:0;padding:0 1rem;-webkit-text-decoration:none;text-decoration:none;text-transform:uppercase;line-height:3.5rem;} .cOAVXU.selected-tab{border-bottom:0.125rem solid #00CDBE !important;} .cOAVXU.selected-tab > .nav-links > a{color:#4A4A4A !important;font-weight:600;} .cOAVXU .selection-indicator-bar{height:0.125rem !important;}.geSvkV{-webkit-box-flex:0 !important;-webkit-flex-grow:0 !important;-ms-flex-positive:0 !important;flex-grow:0 !important;height:3.5rem;box-sizing:border-box;display:none ...

# %%
store_parsed_clean = store_parsed.text.replace(';__NEXT_LOADED_PAGES__=[];__NEXT_REGISTER_PAGE=function(r,f){__NEXT_LOADED_PAGES__.push([r, f])}', '')

# %%
## json.loads(store_parsed_clean)

# %% [markdown]
# ## Licences DF

# %%
licences_df["License Type"].unique()
# Out:
# array(['Cannabis - Distributor Temporary License',
#        'Cannabis - Retailer Temporary License',
#        'Cannabis - Retailer Nonstorefront Temporary License',
#        'Cannabis - Microbusiness Temporary License',
#        'Cannabis - Distributor-Transport Only Temporary License',
#        'Cannabis - Event Organizer Temporary License', 'License Type',
#        'Cannabis - Testing Laboratory Temporary License',
#        'Cannabis - Distributor License', 'Cannabis - Retailer License',
#        'Cannabis - Event Organizer License'], dtype=object)

# %%
glob.glob("..//data//*")
licences_df = pd.read_csv("..//data//searchResults.csv", encoding = "utf-8")
licences_df.head()
# Out:
#         License Number                                       License Type  \
# 0  C11-18-0000939-TEMP           Cannabis - Distributor Temporary License
# 1  C10-18-0000287-TEMP              Cannabis - Retailer Temporary License
# 2   C9-18-0000229-TEMP  Cannabis - Retailer Nonstorefront Temporary Li...
# 3  C12-18-0000217-TEMP         Cannabis - Microbusiness Temporary License
# 4   C9-18-0000230-TEMP  Cannabis - Retailer Nonstorefront Temporary Li...
#
#     Business Owner                       Business Contact Information  \
# 0  Angel Fernandez  MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# 1  Angel Fernandez  MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# 2  Angel Fernandez  MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# 3     Javier Armas  Javier Armas  : Javier's Organics : Email- Jav...
# 4    martha Medina  RGG LLC  : Ruby's Green Garden : Email- rubysg...
#
#           Business Structure  \
# 0                Corporation
# 1                Corporation
# 2                Corporation
# 3        Sole Proprietorship
# 4  Limited Liability Company
#
#                                      Premise Address  Status  Issue Date  \
# 0           CALEXICO, CA 922319530 County: IMPERIAL   Active  07/29/2019
# 1  1632 GATEWAY RD CALEXICO, CA 922319530 County:...  Active  07/29/2019
# 2           CALEXICO, CA 922319530 County: IMPERIAL   Active  07/29/2019
# 3             OAKLAND, CA 946012132 County: ALAMEDA   Active  07/29/2019
# 4             OAKLAND, CA 946012132 County: ALAMEDA   Active  07/29/2019
#
#   Expiration Date                                         Activities  \
# 0      12/31/2018                          N/A for this license type
# 1      12/31/2018                          N/A for this license type
# 2      12/31/2018                          N/A for this license type
# 3      12/31/2018  Level 1 Manufacturer, Retailer Non-Storefront,...
# 4      12/31/2018                          N/A for this license type
#
#   Adult-Use/Medicinal
# 0                BOTH
# 1           Medicinal
# 2                BOTH
# 3                BOTH
# 4                BOTH

# %%
licences_df['Business Contact Information'].head()
# Out:
# 0    MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# 1    MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# 2    MOVOCAN : Email- medigroupangel@gmail.com : Ph...
# 3    Javier Armas  : Javier's Organics : Email- Jav...
# 4    RGG LLC  : Ruby's Green Garden : Email- rubysg...
# Name: Business Contact Information, dtype: object

# %%
licences_df['contact_split'] = licences_df['Business Contact Information'].str.split(':').head()
# licences_df['Business name'] = licences_df['Contact split'].apply(lambda x: x[0])
# licences_df['Business name'].head()
licences_df['contact_split'].head()
# Out:
# 0    [MOVOCAN ,  Email- medigroupangel@gmail.com , ...
# 1    [MOVOCAN ,  Email- medigroupangel@gmail.com , ...
# 2    [MOVOCAN ,  Email- medigroupangel@gmail.com , ...
# 3    [Javier Armas  ,  Javier's Organics ,  Email- ...
# 4    [RGG LLC  ,  Ruby's Green Garden ,  Email- rub...
# Name: contact_split, dtype: object
