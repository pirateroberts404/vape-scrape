# %%
import requests
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import os
import glob
from bs4 import BeautifulSoup
from urllib.request import urlopen
from lxml import html
import sqlite3
import time

# %% [markdown]
# https://docs.python-guide.org/scenarios/scrape/

# %%
def sleep_time(base = 1, tolerance = 1):
    choose = np.random.uniform(0, 1)
    
    if 0 <= choose <= 0.9:
        return np.random.uniform(base, base + tolerance)
    if 0.9 < choose <= 0.99:
        return np.random.uniform((base + tolerance) * 2, (base + tolerance) * 3)
    else:
        return np.random.uniform((base + tolerance) * 6, (base + tolerance) * 7)

# %%
def get_urls():
    '''
    Connects to the weedMaps database and queries for the web_urls.
    Returns a list of web_urls.
    '''
    conn = sqlite3.connect('..//data//weedmaps.db')
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()
    cursor.execute("SELECT web_url FROM store;")

    urls = []
    for row in cursor:
        urls.append(row[0])
    
    conn.close()
    return urls

def get_license_url(web_url):
    '''
    Takes the web_url of a specific dispensary and returns the license numbers and names.
    '''
    try:
        #time.sleep(sleep_time())
        page = requests.get(web_url)
        tree = html.fromstring(page.content)
        license = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[3]')
        license_name = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[1]')
        return license, license_name
        
    except:
        return [], []
        print ("Could not access: " + web_url)
        
def get_licenses():
    urls = get_urls()
    licenses = []
    license_names = []
    for url in urls:
        license, license_name = get_license_url(url)
        licenses.append(license)
        license_names.append(license_name)
    return licenses, license_names

# %%
licenses, license_names = get_licenses()

# %%
license_names
# Out:
# [['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Microbusiness'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Microbusiness'],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  ['Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Retail'],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Retail'],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Cultivation'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  ['Microbusiness'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Distributor', 'Adult-Use Retail', 'Medical Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront', 'Distributor'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront', 'Distributor'],
#  [],
#  ['Adult-Use Retail', 'Adult-Use Retail'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront'],
#  ['Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Medical Retail'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Microbusiness'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Microbusiness'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Microbusiness'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Distributor', 'Adult-Use Retail', 'Medical Nonstorefront'],
#  ['Distributor', 'Adult-Use Retail', 'Medical Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail', 'Distributor', 'Distributor'],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Microbusiness'],
#  ['Microbusiness'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Microbusiness', 'Microbusiness'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Microbusiness'],
#  [],
#  [],
#  ['Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront'],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail'],
#  ['Microbusiness'],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Retail'],
#  ['Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Medical Nonstorefront', 'Distributor', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Retail'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Retail'],
#  ['Medical Retail'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Retail'],
#  ['Medical Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  ['Adult-Use Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Distributor', 'Adult-Use Retail', 'Medical Nonstorefront'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Microbusiness'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Retail'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Microbusiness'],
#  [],
#  [],
#  ['Microbusiness', 'Microbusiness'],
#  ['Medical Retail'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Retail'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Microbusiness', 'Microbusiness'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  ['Adult-Use Nonstorefront'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  ['Microbusiness'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  ['Adult-Use Nonstorefront'],
#  ['Adult-Use Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  ['Adult-Use Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  ['Adult-Use Retail'],
#  ['Adult-Use Retail', 'Medical Retail'],
#  [],
#  [],
#  [],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  [],
#  [],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Medical Retail', 'Adult-Use Retail'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  [],
#  ['Medical Nonstorefront', 'Adult-Use Nonstorefront'],
#  ['Adult-Use Nonstorefront', 'Medical Nonstorefront'],
#  ['Adult-Use Retail'],
#  ...]

# %%
licenses
# Out:
# [['M10-17-0000105-TEMP', 'A10-17-000065-TEMP'],
#  ['A10-17-0000024-TEMP', 'M10-17-0000038-TEMP'],
#  ['M10-18-0000148-TEMP', 'A10-17-000076-TEMP'],
#  ['A12-17-0000007-TEMP'],
#  ['A10-18-0000350-TEMP', 'M10-17-0000058'],
#  ['A10-17-0000004-TEMP'],
#  ['A10-17-0000037-TEMP', 'A10-17-0000037-TEMP'],
#  [],
#  ['A10-18-0000339-TEMP', 'M10-18-0000389-TEMP'],
#  ['M12-18-0000088-TEMP'],
#  [],
#  ['M10-17-0000028-TEMP', 'A10-17-0000016-TEMP'],
#  ['M10-18-0000390-TEMP', 'A10-18-0000340-TEMP'],
#  [],
#  ['A10-18-0000342-TEMP', 'M10-18-0000392-TEMP'],
#  [],
#  ['A10-17-0000038-TEMP', 'M10-17-0000064-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-18-0000108-TEMP', 'A10-18-0000108-TEMP'],
#  ['A910-17-0000087-TEMP'],
#  [],
#  [],
#  ['A10-17-0000016-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-18-0000108-TEMP', 'A10-18-0000108-TEMP'],
#  [],
#  [],
#  [],
#  ['M10-17-0000048-TEMP', 'A10-17-0000032-TEMP'],
#  ['A10-17-0000008-TEMP', 'M10-17-0000034-TEMP'],
#  ['M10-17-0000035-TEMP', 'A10-17-0000021-TEMP'],
#  [],
#  [],
#  ['C10-18C000005-TEMP'],
#  ['A10-17-0000001-TEMP', 'M10-17-0000001-TEMP'],
#  ['M10-17-0000078-TEMP', 'A10-17-0000049-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-18-0000108-TEMP', 'A10-18-0000108-TEMP'],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['C10-18-0000029-TEMP'],
#  ['A10-18-0000125-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  [],
#  [],
#  ['M10-17-0000020-TEMP', 'A10-17-0000011-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  [],
#  [],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  ['C10-18-0000044-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  [],
#  ['A10-18-0000108-TEMP', 'A10-18-0000108-TEMP'],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  ['A10-18-0000108-TEMP', 'A10-18-0000108-TEMP'],
#  ['A10-17-0000016-TEMP'],
#  [],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  ['A10-18-0000108-TEMP', 'A10-18-0000108-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  ['A10-17-0000087-TEMP'],
#  ['TEMP-IN-PROCESS', 'TEMP-IN-PROCESS'],
#  [],
#  ['M12-17-0000015-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['M-10-18-0000363-TEMP', 'M10-18-0000363-TEMP'],
#  ['M9-18-0000108'],
#  [],
#  [],
#  [],
#  ['C9-18-0000093-TEMP ', 'C9-18-0000093-TEMP '],
#  [],
#  [],
#  [],
#  ['C9-18-0000093-TEMP ', 'C9-18-0000093-TEMP '],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['M10-18-0000346-TEMP'],
#  [],
#  [],
#  [],
#  ['C9-18-0000237-Temp'],
#  [],
#  [],
#  ['C9-18-0000237-Temp'],
#  [],
#  ['M9-18-0000108'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C9-18-0000237-Temp'],
#  [],
#  ['C9-18-0000093-TEMP ', 'C9-18-0000093-TEMP '],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['C9-18-0000093-TEMP ', 'C9-18-0000093-TEMP '],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'M9-18-0000076-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'M9-18-0000076-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['102960408-10000'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['102960408-10000'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['601013404'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000090-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'M9-18-0000076-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A10-18-0000324-TEMP'],
#  ['A10-18-0000324-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000033-TEMP', 'M10-17-0000050-TEMP'],
#  ['C10-18-0000049-TEMP'],
#  ['A10-18-0000145-TEMP', 'M10-18-0000187-TEMP'],
#  [],
#  [],
#  ['A10-17-0000037-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['150345'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['5851856621853'],
#  [],
#  [],
#  [],
#  ['C12-18-0000029-TEMP'],
#  ['A9-18-0000090-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C10-18-0000034-TEMP', 'C10-18-0000034-TEMP'],
#  [],
#  ['A9-18-0000093-TEMP', 'M9-18-0000077-TEMP'],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  ['A10-17-0000037-TEMP'],
#  ['A9-18-0000065', 'M9-18-0000069'],
#  ['M9-18-0000067-TEMP'],
#  [],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  [],
#  ['M10-18-0000326-TEMP', 'M10-17-0000149-app'],
#  ['A9-18-0000065', 'M9-18-0000069'],
#  [],
#  ['M9-18-0000070-TEMP'],
#  ['A10-17-0000037-TEMP'],
#  ['M9-17-0000004-TEMP', 'A9-17-0000002-TEMP'],
#  [],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  [],
#  ['C9-18-0000125-TEMP'],
#  ['C9-18-0000030-TEMP'],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  [],
#  ['C9-18-0000004-TEMP', 'C9-18-0000004-TEMP'],
#  [],
#  [],
#  ['C9-18-0000116-TEMP', 'C9-18-0000116-TEMP'],
#  [],
#  ['C9-18-0000152-TEMP', 'C9-18-0000152-TEMP'],
#  ['A9-18-0000093-TEMP', 'M9-18-0000077-TEMP'],
#  [],
#  [],
#  [],
#  ['-----------------------------'],
#  ['928163670'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  [],
#  [],
#  [],
#  [],
#  ['C9-18-0000116-TEMP', 'C9-18-0000116-TEMP'],
#  [],
#  [],
#  ['A9-18-0000101-TEMP', 'M9-18-0000103-TEMP'],
#  [],
#  ['A9-18-0000101-TEMP', 'M9-18-0000103-TEMP'],
#  [],
#  ['C-10-18-0000104-TEMP'],
#  ['C9-18-0000154-TEMP'],
#  [],
#  ['C9-18-0000002-TEMP'],
#  ['M13-18-0000030-TEMP'],
#  [],
#  ['18TMP-009215'],
#  [],
#  [],
#  [],
#  ['C12-18-0000029-TEMP'],
#  [],
#  ['C9-18-0000021-TEMP ', 'C9-18-0000021-TEMP '],
#  ['A9-18-0000060-TEMP', 'M9-18-0000065-TEMP'],
#  [],
#  [],
#  ['C9-18-0000030-TEMP'],
#  [],
#  [],
#  ['M9-18-0000070-TEMP'],
#  ['CAU 051172NS  '],
#  ['928163670'],
#  ['\u200bM9-18-0000267-TEMP'],
#  ['928163670'],
#  ['M9-18-0000070-TEMP'],
#  [],
#  [],
#  ['C12-18-0000029-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000065', 'M9-18-0000069'],
#  ['M9-18-0000085-TEMP', 'A9-18-0000082-TEMP'],
#  ['A9-18-0000082-TEMP', 'M9-18-0000085-TEMP'],
#  [],
#  ['C12-18-0000029-TEMP'],
#  [],
#  ['C9-18-0000002-TEM'],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  ['M9-18-0000059-TEMP'],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  [],
#  [],
#  ['C11-18-0000007-TEMP', 'C11-18-0000007-TEMP'],
#  [],
#  ['C10-18-0000003-TEMP', 'C10-18-0000003-TEMP'],
#  [],
#  ['A10-18-0000218-TEMP', 'M10-18-0000261-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C10-18-0000278-TEMP'],
#  [],
#  ['M10-18-0000262-TEMP', 'A10-18-0000219-TEMP'],
#  [],
#  [],
#  ['M10-18-0000405-TEMP', 'C10-18-0000005-TEMP'],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000023-TEMP'],
#  ['103-132586', '103-132586'],
#  ['C10-18-0000278-TEMP'],
#  [],
#  ['A10-18-0000297-TEMP', 'A10-18-0000297-TEMP'],
#  [],
#  [],
#  ['M10-18-0000267-TEMP', 'A10-18-0000222-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000023-TEMP'],
#  [],
#  [],
#  ['A10-18-0000196-TEMP', 'M10-18-0000243-TEMP'],
#  [],
#  [],
#  ['A10-17-0000087-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C10-18-0000278-TEMP'],
#  [],
#  ['C10-17-0000018-TEMP', 'M10-17-0000018-TEMP'],
#  ['A10-18-0000184-TEMP', 'M10-18-0000236-TEMP'],
#  [],
#  ['A10-17-0000087-TEMP'],
#  ['18TMP-010083'],
#  [],
#  [],
#  [],
#  ['A10-18-0000241-TEMP', 'A10-18-0000241-TEMP'],
#  [],
#  [],
#  ['C10-18-000186-TEMP', 'C10-18-000186-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000085-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-18-0000204-TEMP', 'M10-18-0000245-TEMP'],
#  [],
#  [],
#  ['A10-18-0000326-TEMP',
#   'M10-18-0000374-TEMP',
#   'A11-18-0000293-TEMP',
#   'M11-18-0000335-TEMP'],
#  [],
#  [],
#  [],
#  ['102360092'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-18-0000249-TEMP', 'M10-18-0000273-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A12-18-0000040-TEMP', 'M12-18-0000042-TEMP'],
#  ['C12-18-0000033-Temp'],
#  ['C12-18-0000033-Temp'],
#  ['C10-18-0000023-TEMP', 'C10-18-0000023-TEMP'],
#  ['M10-18-0000294-TEMP', 'A-10-180000263-TEMP'],
#  ['M12-18-0000027TEMP', 'A12-18-0000025TEMP'],
#  ['A-10-180000263-TEMP', 'M10-18-0000294-TEMP'],
#  [],
#  ['A10-18-0000138-TEMP', 'M10-18-0000181-TEMP'],
#  ['A10-18-0000162-TEMP', 'M10-18-0000197-TEMP'],
#  ['M10-18-0000197-TEMP', 'A10-18-0000162-TEMP'],
#  ['M10-18-0000197-TEMP', 'A10-18-0000162-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  [],
#  [],
#  [],
#  ['A9-18-0000090-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['C10-18-0000022-TEMP', 'C10-18-0000022-TEMP'],
#  [],
#  [],
#  [],
#  ['A10-18-0000247-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000028-TEMP', 'M10-17-0000044-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C12-18-0000185'],
#  [],
#  [],
#  ['181517708'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-18-0000227-TEMP'],
#  ['A10-18-0000324-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['M9-18-0000104-TEMP'],
#  [],
#  ['A10-17-0000020-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['1122143557'],
#  ['A10-18-0000227-TEMP'],
#  ['M10-17-0000010-TEMP'],
#  ['C12-18-0000124-TEMP'],
#  [],
#  [],
#  ['A10-18-0000227-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000026-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['M10-18-0000348-TEMP', 'A10-18-0000302-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['M10-180000191-TEMP'],
#  ['M10-18-0000333-TEMP'],
#  ['A10-18-0000101-Temp', 'M10-18-0000144-Temp'],
#  ['A10-18-0000162-TEMP', 'M10-18-0000197-TEMP'],
#  [],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  ['A10-18-0000231-TEMP', 'M10-18-0000279-TEMP'],
#  ['C10-18-0000019-TEMP', 'C10-18-0000019-TEMP'],
#  ['A10-18-0000162-TEMP', 'M10-18-0000197-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  [],
#  ['M10-18-0000207-TEMP'],
#  ['M10-18-0000197-TEMP', 'A10-18-0000162-TEMP'],
#  ['M9-18-0000065-TEMP', 'A9-18-0000060'],
#  ['A10-17-0000087-TEMP'],
#  ['A10-18-0000308-TEMP'],
#  ['C10-18-0000094-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  ['A9-17-0000002-TEMP'],
#  [],
#  ['C9-18-0000004-TEMP', 'C9-18-0000004-TEMP'],
#  [],
#  [],
#  ['M9-18-0000077-TEMP', 'A9-18-0000093-TEMP'],
#  ['M10-18-0000237-TEMP'],
#  ['M10-18-0000302-TEMP'],
#  [],
#  ['C9-18-0000002'],
#  ['C9-18-0000007-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['M10-18-0000208-TEMP'],
#  ['M10-18-0000274-TEMP'],
#  [],
#  ['A10-18-0000106-TEMP', 'A10-18-0000106-TEMP'],
#  ['c3962428'],
#  ['M9-18-0000044-TEMP', 'A9-18-0000037-TEMP'],
#  ['M9-18-0000028-TEMP', 'A9-18-0000026-TEMP'],
#  ['A10-18-0000270-TEMP', 'A10-18-0000270-TEMP'],
#  ['A10-18-0000162-TEMP', 'M10-18-0000197-TEMP'],
#  [],
#  ['A9-18-0000037-TEMP', 'M9-18-0000044-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  ['A10-18-0000355-TEMP', 'M10-18-0000343-TEMP'],
#  ['M10-18-0000197-TEMP', 'A10-18-0000162-TEMP'],
#  ['M9-18-0000028-TEMP', 'A9-18-0000026-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  ['M10-18-0000197-TEMP', 'A10-18-0000162-TEMP'],
#  ['A9-18-0000037-TEMP', 'M9-18-0000044-TEMP'],
#  ['A9-18-0000035-TEMP'],
#  ['C10-18-0000009-TEMP', 'C10-18-0000009-TEMP'],
#  [],
#  ['A10-18-0000291-TEMP', 'M10-18-0000328-TEMP'],
#  ['A10-17-0000063-TEMP'],
#  ['A10-18-0000272-TEMP', 'M10-18-0000160-TEMP'],
#  [],
#  [],
#  ['C9-18-0000025-TEMP', 'C9-18-0000025-TEMP'],
#  ['M9-18-0000023-Temp', 'A9-17-000000-Temp'],
#  [],
#  [],
#  ['M10-18-0000193-TEMP', 'A10-18-0000193-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['M9-18-0000028-TEMP', 'A9-18-0000026-TEMP'],
#  ['M9-18-0000065-TEMP', 'A9-18-0000060-TEMP'],
#  [],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['A9-18-0000090-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A10-17-0000045-TEMP'],
#  ['A9-180000042', 'A9-180000042', 'A9-180000042'],
#  ['19-00132752', 'M10-18-0000166-TEMP'],
#  ['M10-17-0000011-TEMP', 'A10-17-0000007-TEMP'],
#  ['A10-18-0000162-TEMP', 'M10-18-0000197-TEMP'],
#  ['C9-18-0000085-TEMP'],
#  [],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  ['C9-18-0000085-TEMP'],
#  ['c9-18-0000040-temp'],
#  ['C9-18-0000085-TEMP'],
#  [],
#  [],
#  ['c9-18-0000040-temp'],
#  ['C12-18-0000010-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  [],
#  [],
#  [],
#  ['C10-18-0000071-TEMP'],
#  ['M-10-18-0000401-TEMP', 'A-10-18-0000349-TEMP'],
#  ['M10-18-0000185'],
#  [],
#  ['C9-18-0000085-TEMP'],
#  ['C9-18-0000085-TEMP'],
#  ['A9-18-0000030-TEMP', 'M9-18-0000042-TEMP'],
#  ['c9-18-0000040-temp'],
#  [],
#  ['C9-18-0000115-TEMP'],
#  ['A9-18-0000035-TEMP'],
#  [],
#  ['C9-18-0000040-TEMP'],
#  ['C9-18-0000018-TEMP', 'C9-18-0000018-TEMP'],
#  ['c9-18-0000040-temp'],
#  ['A9-18-0000030-TEMP', 'M9-18-0000042-TEMP'],
#  ['A12-18-0000032-TEMP'],
#  [],
#  [],
#  ['A12-18-0000078-TEMP', 'M12-18-0000074-TEMP'],
#  ['C10-18-00000-TEMP'],
#  [],
#  ['c9-18-0000040-temp'],
#  ['c9-18-0000040-temp'],
#  ['C9-18-0000121-TEMP'],
#  [],
#  ['c9-18-0000040-temp'],
#  ['C9-18-0000025-TEMP', 'C9-18-0000025-TEMP'],
#  [],
#  [],
#  [],
#  ['A9-18-0000035-TEMP'],
#  ['M10-18-0000279-TEMP', 'A10-18-0000231-TEMP'],
#  [],
#  ['A9-18-0000094-TEMP'],
#  [],
#  [],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  [],
#  [],
#  ['A9-18-0000030-TEMP', 'M9-18-0000042-TEMP'],
#  [],
#  [],
#  ['A9-18-0000035-TEMP'],
#  [],
#  ['C9-18-0000025-TEMP', 'C9-18-0000025-TEMP'],
#  ['c10-0000002-lic', 'c10-0000002-lic'],
#  ['A9-18-0000035-TEMP'],
#  ['A9-18-0000035-TEMP'],
#  ['A9-18-0000035-TEMP'],
#  [],
#  ['A12-18-0000082-TEMP', 'M12-18-0000078-TEMP'],
#  ['C9-18-000132-TEMP', 'C9-18-000132-TEMP'],
#  ['C-9-18-0000004', 'C-9-18-0000004'],
#  [],
#  [],
#  [],
#  ['A9-18-0000035-TEMP'],
#  [],
#  ['A9-18-0000035-TEMP'],
#  ['A9-18-0000035-TEMP'],
#  ['C9-18-0000018-TEMP', 'C9-18-0000018-TEMP'],
#  [],
#  ['M10-18-0000401-TEMP'],
#  [],
#  [],
#  ['C9-18-0000057-TEMP', 'C9-18-0000057-TEMP'],
#  [],
#  [],
#  ['C9-18-0000057-TEMP', 'C9-18-0000057-TEMP'],
#  ['A9-18-0000035-TEMP'],
#  [],
#  ['C9-18-0000084-TEMP', 'C9-18-0000084-TEMP'],
#  ['M9-18-0000024-TEMP', 'A9-18-0000023-TEMP'],
#  ['A12-18-0000083-TEMP', 'M12-18-0000079-TEMP'],
#  [],
#  ['C9-18-0000018-TEMP', 'C9-18-0000018-TEMP'],
#  [],
#  [],
#  ['M9-170000012-TEMP', 'A9-180000050-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['TLO-SICO'],
#  [],
#  [],
#  ['TLO-SICO'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C10-18-0000178-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['c10-18-00000259-temp'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['C9-18-0000028-TEMP'],
#  ['M10-17-0000009-TEMP', 'M10-17-0000009- TEMP'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A10-17-0000009-TEMP ', 'M10-17-0000016-TEMP'],
#  ['M10-17-0000030-TEMP', 'A10-17-0000018-TEMP'],
#  [],
#  ['C12-18-0000211-TEMP'],
#  ['A10-17-0000003-TEMP', 'M10-17-0000003-TEMP'],
#  ['A10-18-0000126-TEMP', 'A10-18-0000126-TEMP'],
#  [],
#  ['A9-18-0000035-TEMP'],
#  ['A10-17-0000044-TEMP'],
#  ['M10-18-0000379-TEMP', 'A10-18-0000327-TEMP'],
#  ['M9-18-0000028-TEMP', 'A9-18-0000026-TEMP'],
#  ['A10-17-0000089-TEMP', 'M10-17-0000137-TEMP'],
#  ['C10-18-0000065-TEMP', 'C10-18-0000065-TEMP'],
#  ['C10-18-0000204-TEMP', 'C10-18-0000204-TEMP'],
#  ['M9-18-0000044-TEMP', 'A9-18-0000037-TEMP'],
#  [],
#  ['C10-18-0000090', 'C10-18-0000090'],
#  [],
#  ['C10-18-0000057-TEMP'],
#  ['M10-17-0000036-TEMP', 'A10-17-0000022-TEMP'],
#  [],
#  [],
#  ['A10-17-0000002-TEMP', 'M10-17-0000002-TEMP'],
#  ['A10-17-0000089-TEMP', 'M10-17-0000137-TEMP'],
#  [],
#  [],
#  ['A10-17-0000036-TEMP', 'M10-17-0000060-TEMP'],
#  ['A9-17-000000-Temp', 'M9-18-0000023-Temp'],
#  ['C10-18-0000144-TEMP', 'C10-18-0000144-TEMP'],
#  ['A10-17-0000047-TEMP', 'M10-17-0000075-TEMP'],
#  ['A10-17-0000043-TEMP', 'M10-17-0000096-TEMP'],
#  ['A10-17-0000067-TEMP'],
#  ['A10-17-0000057-TEMP', 'M10-17-0000067-TEMP'],
#  [],
#  [],
#  [],
#  [],
#  ['A9-18-0000047', 'M9-18-0000053'],
#  [],
#  [],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['M10-17-0000060-TEMP', 'A10-17-0000036-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  [],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['A9-18-0000075-TEMP', 'A9-18-0000075-TEMP'],
#  ['C10-18-0000038'],
#  ...]

# %%
from itertools import chain
np.unique(list(chain.from_iterable((license_names))))
# Out:
# array(['Adult-Use Cultivation', 'Adult-Use Nonstorefront',
#        'Adult-Use Retail', 'Distributor', 'Medical Cultivation',
#        'Medical Nonstorefront', 'Medical Retail', 'Microbusiness'],
#       dtype='<U23')

# %% [markdown]
# Create table with store_id, license_name, license_type

# %%
page = requests.get("https://weedmaps.com/dispensaries/the-crop")
tree = html.fromstring(page.content)

license = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[3]')
license_name = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[1]')
license, license_name
# Out:
# (['C10-18-0000178-TEMP'], ['Medical Retail'])

# %%
page = requests.get("https://weedmaps.com/dispensaries/natural-healing-center")
tree = html.fromstring(page.content)

license = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[3]')
license_name = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[1]')
license, license_name
# Out:
# (['M-10-18-0000363-TEMP', 'M10-18-0000363-TEMP'],
#  ['Adult-Use Retail', 'Medical Retail'])

# %%
page = requests.get("https://weedmaps.com/dispensaries/805-beach-breaks")
tree = html.fromstring(page.content)

license = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[3]')
license_name = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[1]')
license, license_name
# Out:
# (['M10-18-0000346-TEMP'], ['Adult-Use Retail'])

# %%
## No licenses
page = requests.get("https://weedmaps.com/deliveries/cloud-9-collective-san-luis-obispo")
tree = html.fromstring(page.content)

license = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[3]')
license_name = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/ul/li/text()[1]')
license, license_name
# Out:
# ([], [])

# %%
page = requests.get('https://weedmaps.com/deliveries/cloud-9-collective-san-luis-obispo')
tree = html.fromstring(page.content)
phone = tree.xpath('//*[@id="collapsible-container"]/div[1]/div[1]/div[1]/ul/li[1]/a/href/')
# Out:
# []
