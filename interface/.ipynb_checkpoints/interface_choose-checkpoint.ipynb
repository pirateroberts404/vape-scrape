# %%
import pandas as pd
import numpy as np
import sqlite3
import glob
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
import re

# %%
not_joined_df = pd.read_csv("..//data//weedmaps_not_joined.csv")
joined_df = pd.read_csv("..//data//weedmaps_joined.csv")
licenses_df = pd.read_csv("..//data//searchResultsClean.csv")

# %%
wm_df =  pd.read_csv("..//data//weedmaps_not_joined.csv")

# %%
wm_df.drop('id', axis = 1)
# Out:
#      Unnamed: 0  Unnamed: 0.1                                 name       state                    city   latitude   longitude  license_type                      address  rating  reviews_count zip_code                                                                          web_url retailer_services            phone  adult_use_cultivation adult_use_nonstorefront adult_use_retail  distributor  medical_cultivation medical_nonstorefront  medical_retail microbusiness
# 0    11          11            Lytt                                 CA          Pacifica                37.634507 -122.491800  medical       1905 Palmetto Ave. Unit B    4.0     104            94044    https://weedmaps.com/dispensaries/surefyre                                       storefront        0000000000      NaN                     NaN                     NaN             NaN          NaN                   NaN                   NaN             NaN
# ...

# %%
licenses_df.head()
# Out:
#         License Number                                         License Type   Business Owner                                                                 Business Contact Information         Business Structure                                          Premise Address  Status  Issue Date Expiration Date                                                  Activities Adult-Use/Medicinal  zip_code      city                             email          website  company_name         phone  master_index        clean_name
# ...

# %%
licenses_df.head()
# Out:
#         License Number                                         License Type   Business Owner                                                                 Business Contact Information         Business Structure                                          Premise Address  Status  Issue Date Expiration Date                                                  Activities Adult-Use/Medicinal  zip_code      city                             email          website  company_name         phone  master_index        clean_name
# ...

# %%
licenses_df['clean_name'] = licenses_df['License Number'].str.replace('-', '')

# %%
with open('latent.json', 'w') as data_file:
    json.dump(json_data, data_file)

# %%
with open('latent.json') as data_file:    
    data = json.load(data_file)

# %%
with open('matches copy.json') as suggestions_file:    
    suggest = json.load(suggestions_file)

# %%
suggest
# Out:
# {'0': [[26079, 2], [30861, 2], [38583, 1]],
#  '1': [[26079, 2], [30861, 2], [38583, 1]],
#  '10': [[434, 1]],
#  '11': [[6028, 2],
#   [17464, 2],
#   [6380, 1],
#   [33364, 1],
#   [46369, 1],
#   [24008, 1],
#   [26678, 1],
#   [15472, 1],
#   [59790, 1],
#   [44318, 1],
#   [18351, 1],
#   [44366, 1]],
#  '12': [[6380, 2],
#   [33364, 1],
#   [6028, 1],
#   [46369, 1],
#   [24008, 1],
#   [26678, 1],
#   [15472, 1],
#   [17464, 1],
#   [59790, 1],
#   [44318, 1],
#   [18351, 1],
#   [44366, 1]],
#  '13': [[59790, 2],
#   [6380, 1],
#   [33364, 1],
#   [6028, 1],
#   [46369, 1],
#   [24008, 1],
#   [26678, 1],
#   [15472, 1],
#   [17464, 1],
#   [44318, 1],
#   [18351, 1],
#   [44366, 1]],
#  '14': [[59790, 2],
#   [6380, 1],
#   [33364, 1],
#   [6028, 1],
#   [46369, 1],
#   [24008, 1],
#   [26678, 1],
#   [15472, 1],
#   [17464, 1],
#   [44318, 1],
#   [18351, 1],
#   [44366, 1]],
#  '15': [[50030, 2],
#   [7779, 1],
#   [56361, 1],
#   [34073, 1],
#   [18152, 1],
# ...

# %%
for key in list(suggest.keys()):
    license_key = licenses_df[licenses_df['master_index'] == int(key)]['clean_name'].values[0]
    suggest[str(license_key)] = suggest.pop(key)

# %%
with open('clean_matches.json', 'w') as clean_file:
    json.dump(suggest, clean_file)

# %%
suggest
# Out:
# {'C10180000287TEMP': [[26079, 2], [30861, 2], [38583, 1]],
#  'C10180000288TEMP': [[45164, 2]],
#  'C11180000939TEMP': [[26079, 2], [30861, 2], [38583, 1]],
#  'C11180000940TEMP': [[6028, 2],
#   [17464, 2],
#   [6380, 1],
#   [33364, 1],
#   [46369, 1],
#   [24008, 1],
#   [26678, 1],
#   [15472, 1],
#   [59790, 1],
#   [44318, 1],
#   [18351, 1],
#   [44366, 1]],
#  'C11180000941TEMP': [[7779, 2],
#   [56361, 1],
#   [50030, 1],
#   [34073, 1],
#   [18152, 1],
#   [21524, 1],
#   [4706, 1]],
#  'C11180000942TEMP': [[59790, 2],
#   [6380, 1],
#   [33364, 1],
#   [6028, 1],
#   [46369, 1],
#   [24008, 1],
#   [26678, 1],
#   [15472, 1],
#   [17464, 1],
#   [44318, 1],
#   [18351, 1],
#   [44366, 1]],
#  'C11180000943TEMP': [[434, 1]],
#  'C11180000944TEMP': [[50030, 2],
#   [7779, 1],
#   [56361, 1],
#   [34073, 1],
#   [18152, 1],
#   [21524, 1],
#   [4706, 1]],
#  'C11180000945TEMP': [[44318, 2],
#   [6380, 1],
#   [33364, 1],
#   [6028, 1],
#   [46369, 1],
#   [24008, 1],
# ...

# %%
C13180000163TEMP
